# %%
import numpy as np
import pandas as pd
import cv2
from PIL import Image
import os
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 3
#       1 import numpy as np
#       2 import pandas as pd
# ----> 3 import cv2
#       4 from PIL import Image
#       5 import os
#
# ModuleNotFoundError: No module named 'cv2'

# %%
image_directory_day1 = 'AutoML/TomatoDatasetPPM3/Day1 - 16.08.22/CLIPPED/'
image_dataset_1 = []
images = os.listdir(image_directory_day1)
for i, image_name in enumerate(images):    #Remember enumerate method adds a counter and returns the enumerate object
    if (image_name.split('.')[1] == 'ppm'):
        #print(image_directory+image_name)
        image = cv2.imread(image_directory_day1+image_name, 1)
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        image = Image.fromarray(image)
        image_dataset_1.append(np.array(image))
image_dataset_1 = np.array(image_dataset_1)
image_dataset_1.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 image_directory_day1 = 'AutoML/TomatoDatasetPPM3/Day1 - 16.08.22/CLIPPED/'
#       2 image_dataset_1 = []
# ----> 3 images = os.listdir(image_directory_day1)
#       4 for i, image_name in enumerate(images):    #Remember enumerate method adds a counter and returns the enumerate object
#       5     if (image_name.split('.')[1] == 'ppm'):
#       6         #print(image_directory+image_name)
#
# NameError: name 'os' is not defined

# %%
plt.imshow(image_dataset_1[0])

# %%
image_directory_day2 = '../TomatoDatasetPPM3/Day2 - 17.08.22/CLIPPED/'
image_dataset_2 = []
images = os.listdir(image_directory_day2)
for i, image_name in enumerate(images):    #Remember enumerate method adds a counter and returns the enumerate object
    if (image_name.split('.')[1] == 'ppm'):
        #print(image_directory+image_name)
        image = cv2.imread(image_directory_day2+image_name, 1)
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        image = Image.fromarray(image)
        image_dataset_2.append(np.array(image))
image_dataset_2 = np.array(image_dataset_2)
image_dataset_2.shape
# Out:
# (75, 64, 64, 3)

# %%
image_directory_day3 = '../TomatoDatasetPPM3/Day3 - 18.08.22/CLIPPED/'
image_dataset_3 = []
images = os.listdir(image_directory_day3)
for i, image_name in enumerate(images):    #Remember enumerate method adds a counter and returns the enumerate object
    if (image_name.split('.')[1] == 'ppm'):
        #print(image_directory+image_name)
        image = cv2.imread(image_directory_day3+image_name, 1)
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        image = Image.fromarray(image)
        image_dataset_3.append(np.array(image))
image_dataset_3 = np.array(image_dataset_3)
image_dataset_3.shape
# Out:
# (90, 64, 64, 3)

# %%
image_directory_day4 = '../TomatoDatasetPPM3/Day4 - 19.08.22/CLIPPED/'
image_dataset_4 = []
images = os.listdir(image_directory_day4)
for i, image_name in enumerate(images):    #Remember enumerate method adds a counter and returns the enumerate object
    if (image_name.split('.')[1] == 'ppm'):
        #print(image_directory+image_name)
        image = cv2.imread(image_directory_day4+image_name, 1)
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        image = Image.fromarray(image)
        image_dataset_4.append(np.array(image))
image_dataset_4 = np.array(image_dataset_4)
image_dataset_4.shape
# Out:
# (82, 64, 64, 3)

# %% [markdown]
# ### Making HSV images

# %%
image_directory_day1 = '../TomatoDatasetPPM3/Day1 - 16.08.22/CLIPPED/'
HSV_dataset_1 = []
images = os.listdir(image_directory_day1)
for i, image_name in enumerate(images):    #Remember enumerate method adds a counter and returns the enumerate object
    if (image_name.split('.')[1] == 'ppm'):
        #print(image_directory+image_name)
        image = cv2.imread(image_directory_day1+image_name, 1)
        image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
        image = Image.fromarray(image)
        HSV_dataset_1.append(np.array(image))
HSV_dataset_1 = np.array(HSV_dataset_1)
print(HSV_dataset_1.shape)

image_directory_day2 = '../TomatoDatasetPPM3/Day2 - 17.08.22/CLIPPED/'
HSV_dataset_2 = []
images = os.listdir(image_directory_day2)
for i, image_name in enumerate(images):    #Remember enumerate method adds a counter and returns the enumerate object
    if (image_name.split('.')[1] == 'ppm'):
        #print(image_directory+image_name)
        image = cv2.imread(image_directory_day2+image_name, 1)
        image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
        image = Image.fromarray(image)
        HSV_dataset_2.append(np.array(image))
HSV_dataset_2 = np.array(HSV_dataset_2)
print(HSV_dataset_2.shape)

image_directory_day3 = '../TomatoDatasetPPM3/Day3 - 18.08.22/CLIPPED/'
HSV_dataset_3 = []
images = os.listdir(image_directory_day3)
for i, image_name in enumerate(images):    #Remember enumerate method adds a counter and returns the enumerate object
    if (image_name.split('.')[1] == 'ppm'):
        #print(image_directory+image_name)
        image = cv2.imread(image_directory_day3+image_name, 1)
        image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
        image = Image.fromarray(image)
        HSV_dataset_3.append(np.array(image))
HSV_dataset_3 = np.array(HSV_dataset_3)
print(HSV_dataset_3.shape)

image_directory_day4 = '../TomatoDatasetPPM3/Day4 - 19.08.22/CLIPPED/'
HSV_dataset_4 = []
images = os.listdir(image_directory_day4)
for i, image_name in enumerate(images):    #Remember enumerate method adds a counter and returns the enumerate object
    if (image_name.split('.')[1] == 'ppm'):
        #print(image_directory+image_name)
        image = cv2.imread(image_directory_day4+image_name, 1)
        image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
        image = Image.fromarray(image)
        HSV_dataset_4.append(np.array(image))
HSV_dataset_4 = np.array(HSV_dataset_4)
print(HSV_dataset_4.shape)
# Out:
# (60, 64, 64, 3)
# (75, 64, 64, 3)
# (90, 64, 64, 3)
# (82, 64, 64, 3)

# %%
plt.imshow(HSV_dataset_1[0])

# %% [markdown]
# ### making LAB dataset

# %%
image_directory_day1 = '../TomatoDatasetPPM3/Day1 - 16.08.22/CLIPPED/'
LAB_dataset_1 = []
images = os.listdir(image_directory_day1)
for i, image_name in enumerate(images):    #Remember enumerate method adds a counter and returns the enumerate object
    if (image_name.split('.')[1] == 'ppm'):
        #print(image_directory+image_name)
        image = cv2.imread(image_directory_day1+image_name, 1)
        image = cv2.cvtColor(image, cv2.COLOR_BGR2LAB)
        image = Image.fromarray(image)
        LAB_dataset_1.append(np.array(image))
LAB_dataset_1 = np.array(LAB_dataset_1)
print(LAB_dataset_1.shape)

image_directory_day2 = '../TomatoDatasetPPM3/Day2 - 17.08.22/CLIPPED/'
LAB_dataset_2 = []
images = os.listdir(image_directory_day2)
for i, image_name in enumerate(images):    #Remember enumerate method adds a counter and returns the enumerate object
    if (image_name.split('.')[1] == 'ppm'):
        #print(image_directory+image_name)
        image = cv2.imread(image_directory_day2+image_name, 1)
        image = cv2.cvtColor(image, cv2.COLOR_BGR2LAB)
        image = Image.fromarray(image)
        LAB_dataset_2.append(np.array(image))
LAB_dataset_2 = np.array(LAB_dataset_2)
print(LAB_dataset_2.shape)

image_directory_day3 = '../TomatoDatasetPPM3/Day3 - 18.08.22/CLIPPED/'
LAB_dataset_3 = []
images = os.listdir(image_directory_day3)
for i, image_name in enumerate(images):    #Remember enumerate method adds a counter and returns the enumerate object
    if (image_name.split('.')[1] == 'ppm'):
        #print(image_directory+image_name)
        image = cv2.imread(image_directory_day3+image_name, 1)
        image = cv2.cvtColor(image, cv2.COLOR_BGR2LAB)
        image = Image.fromarray(image)
        LAB_dataset_3.append(np.array(image))
LAB_dataset_3 = np.array(LAB_dataset_3)
print(LAB_dataset_3.shape)

image_directory_day4 = '../TomatoDatasetPPM3/Day4 - 19.08.22/CLIPPED/'
LAB_dataset_4 = []
images = os.listdir(image_directory_day4)
for i, image_name in enumerate(images):    #Remember enumerate method adds a counter and returns the enumerate object
    if (image_name.split('.')[1] == 'ppm'):
        #print(image_directory+image_name)
        image = cv2.imread(image_directory_day4+image_name, 1)
        image = cv2.cvtColor(image, cv2.COLOR_BGR2LAB)
        image = Image.fromarray(image)
        LAB_dataset_4.append(np.array(image))
LAB_dataset_4 = np.array(LAB_dataset_4)
print(LAB_dataset_4.shape)
# Out:
# (60, 64, 64, 3)
# (75, 64, 64, 3)
# (90, 64, 64, 3)
# (82, 64, 64, 3)

# %%
plt.imshow(LAB_dataset_1[0])

# %%
def conver(class123,channel):
    meanlist = []
    stdlist = []
    minlist = []
    maxlist = []
    varlist = []
    for i in range(class123.shape[0]):
        meanlist.append(np.mean(class123[i,:,:,channel])),
        stdlist.append(np.std(class123[i,:,:,channel])),
        minlist.append(np.min(class123[i,:,:,channel])),
        maxlist.append(np.max(class123[i,:,:,channel])),
        varlist.append(np.var(class123[i,:,:,channel])),
    meanlist = np.array(meanlist,dtype='float32')
    stdlist = np.array(stdlist,dtype='float32')
    minlist = np.array(minlist,dtype='int32')
    maxlist = np.array(maxlist,dtype='int32')
    varlist = np.array(varlist,dtype='float32')
    return meanlist,stdlist,minlist,maxlist,varlist

# %%
# image_dataset1 is of class 1

# %%
mean1, std1, min1, max1, var1 = conver(image_dataset_1,0)
mean2, std2, min2, max2, var2 = conver(image_dataset_1,1)
mean3, std3, min3, max3, var3 = conver(image_dataset_1,2)

mean4, std4, min4, max4, var4 = conver(HSV_dataset_1,0)
mean5, std5, min5, max5, var5 = conver(HSV_dataset_1,1)
mean6, std6, min6, max6, var6 = conver(HSV_dataset_1,2)

mean7, std7, min7, max7, var7 = conver(LAB_dataset_1,0)
mean8, std8, min8, max8, var8 = conver(LAB_dataset_1,1)
mean9, std9, min9, max9, var9 = conver(LAB_dataset_1,2)

# %%
cl1_df = pd.DataFrame()

# %%
cl1_df['mean_r'] = mean1
cl1_df['std_r'] = std1 
cl1_df['min_r'] = min1
cl1_df['max_r'] = max1
cl1_df['var_r'] = var1

cl1_df['mean_g'] = mean2
cl1_df['std_g'] = std2
cl1_df['min_g'] = min2
cl1_df['max_g'] = max2
cl1_df['var_g'] = var2

cl1_df['mean_b'] = mean3
cl1_df['std_b'] = std3
cl1_df['min_b'] = min3
cl1_df['max_b'] = max3
cl1_df['var_b'] = var3

cl1_df['mean_h'] = mean4
cl1_df['std_h'] = std4 
cl1_df['min_h'] = min4
cl1_df['max_h'] = max4
cl1_df['var_h'] = var4

cl1_df['mean_s'] = mean5
cl1_df['std_s'] = std5
cl1_df['min_s'] = min5
cl1_df['max_s'] = max5
cl1_df['var_s'] = var5

cl1_df['mean_v'] = mean6
cl1_df['std_v'] = std6
cl1_df['min_v'] = min6
cl1_df['max_v'] = max6
cl1_df['var_v'] = var6

cl1_df['mean_l'] = mean7
cl1_df['std_l'] = std7
cl1_df['min_l'] = min7
cl1_df['max_l'] = max7
cl1_df['var_l'] = var7

cl1_df['mean_a'] = mean8
cl1_df['std_a'] = std8
cl1_df['min_a'] = min8
cl1_df['max_a'] = max8
cl1_df['var_a'] = var8

cl1_df['mean_b1'] = mean9
cl1_df['std_b1'] = std9
cl1_df['min_b1'] = min9
cl1_df['max_b1'] = max9
cl1_df['var_b1'] = var9

cl1_df
# Out:
#         mean_r      std_r  min_r  max_r        var_r      mean_g      std_g  \
# 0   193.134766  39.782333     88    248  1582.634155  171.823242  35.688812
# 1   193.628906  39.693394     80    248  1575.565430  171.774414  35.723545
# 2   185.572266  37.156509     80    248  1380.606079  171.995117  33.045601
# 3   193.136719  41.929501     40    248  1758.082886  170.148438  37.029568
# 4   194.707031  38.719547     88    248  1499.203247  171.323242  35.665424
# 5   194.082031  39.359833     88    248  1549.196411  173.161133  35.749775
# 6   193.669922  39.728870     88    248  1578.383179  171.701172  35.226673
# 7   195.371094  39.300262     88    248  1544.510742  172.575195  34.751366
# 8   189.896484  38.760849    104    248  1502.403320  165.525391  29.021835
# 9   188.623047  39.169334    104    248  1534.236816  164.337891  28.988600
# 10  192.271484  39.613026     96    248  1569.191895  169.123047  34.552788
# ...

# %%
cl1_df ['Target'] = 0
cl1_df
# Out:
#         mean_r      std_r  min_r  max_r        var_r      mean_g      std_g  \
# 0   193.134766  39.782333     88    248  1582.634155  171.823242  35.688812
# 1   193.628906  39.693394     80    248  1575.565430  171.774414  35.723545
# 2   185.572266  37.156509     80    248  1380.606079  171.995117  33.045601
# 3   193.136719  41.929501     40    248  1758.082886  170.148438  37.029568
# 4   194.707031  38.719547     88    248  1499.203247  171.323242  35.665424
# 5   194.082031  39.359833     88    248  1549.196411  173.161133  35.749775
# 6   193.669922  39.728870     88    248  1578.383179  171.701172  35.226673
# 7   195.371094  39.300262     88    248  1544.510742  172.575195  34.751366
# 8   189.896484  38.760849    104    248  1502.403320  165.525391  29.021835
# 9   188.623047  39.169334    104    248  1534.236816  164.337891  28.988600
# 10  192.271484  39.613026     96    248  1569.191895  169.123047  34.552788
# ...

# %%
mean1, std1, min1, max1, var1 = conver(image_dataset_2,0)
mean2, std2, min2, max2, var2 = conver(image_dataset_2,1)
mean3, std3, min3, max3, var3 = conver(image_dataset_2,2)

mean4, std4, min4, max4, var4 = conver(HSV_dataset_2,0)
mean5, std5, min5, max5, var5 = conver(HSV_dataset_2,1)
mean6, std6, min6, max6, var6 = conver(HSV_dataset_2,2)

mean7, std7, min7, max7, var7 = conver(LAB_dataset_2,0)
mean8, std8, min8, max8, var8 = conver(LAB_dataset_2,1)
mean9, std9, min9, max9, var9 = conver(LAB_dataset_2,2)

# %%
cl2_df = pd.DataFrame()

# %%
cl2_df['mean_r'] = mean1
cl2_df['std_r'] = std1 
cl2_df['min_r'] = min1
cl2_df['max_r'] = max1
cl2_df['var_r'] = var1

cl2_df['mean_g'] = mean2
cl2_df['std_g'] = std2
cl2_df['min_g'] = min2
cl2_df['max_g'] = max2
cl2_df['var_g'] = var2

cl2_df['mean_b'] = mean3
cl2_df['std_b'] = std3
cl2_df['min_b'] = min3
cl2_df['max_b'] = max3
cl2_df['var_b'] = var3

cl2_df['mean_h'] = mean4
cl2_df['std_h'] = std4 
cl2_df['min_h'] = min4
cl2_df['max_h'] = max4
cl2_df['var_h'] = var4

cl2_df['mean_s'] = mean5
cl2_df['std_s'] = std5
cl2_df['min_s'] = min5
cl2_df['max_s'] = max5
cl2_df['var_s'] = var5

cl2_df['mean_v'] = mean6
cl2_df['std_v'] = std6
cl2_df['min_v'] = min6
cl2_df['max_v'] = max6
cl2_df['var_v'] = var6

cl2_df['mean_l'] = mean7
cl2_df['std_l'] = std7
cl2_df['min_l'] = min7
cl2_df['max_l'] = max7
cl2_df['var_l'] = var7

cl2_df['mean_a'] = mean8
cl2_df['std_a'] = std8
cl2_df['min_a'] = min8
cl2_df['max_a'] = max8
cl2_df['var_a'] = var8

cl2_df['mean_b1'] = mean9
cl2_df['std_b1'] = std9
cl2_df['min_b1'] = min9
cl2_df['max_b1'] = max9
cl2_df['var_b1'] = var9

cl2_df
# Out:
#         mean_r      std_r  min_r  max_r        var_r      mean_g      std_g  \
# 0   197.257812  25.174623    112    248   633.761658  180.057617  27.488930
# 1   162.853516  27.862350     80    248   776.310547  149.349609  23.541162
# 2   167.146484  30.303768     80    248   918.318359  154.097656  31.088305
# 3   178.410156  34.980850     88    248  1223.659912  162.339844  37.052563
# 4   166.712891  27.768848     88    248   771.108948  152.118164  24.858618
# ..         ...        ...    ...    ...          ...         ...        ...
# 70  157.341797  31.331587     80    248   981.668335  143.968750  25.747705
# 71  159.431641  31.349922     88    248   982.817566  145.350586  25.888737
# 72  158.363281  30.182920     80    248   911.008667  147.278320  24.634966
# 73  149.947266  28.292921     72    248   800.489380  144.090820  23.408806
# 74  150.589844  26.907461     72    248   724.011475  145.157227  23.241611
#
# ...

# %%
cl2_df ['Target'] = 1
cl2_df
# Out:
#         mean_r      std_r  min_r  max_r        var_r      mean_g      std_g  \
# 0   197.257812  25.174623    112    248   633.761658  180.057617  27.488930
# 1   162.853516  27.862350     80    248   776.310547  149.349609  23.541162
# 2   167.146484  30.303768     80    248   918.318359  154.097656  31.088305
# 3   178.410156  34.980850     88    248  1223.659912  162.339844  37.052563
# 4   166.712891  27.768848     88    248   771.108948  152.118164  24.858618
# ..         ...        ...    ...    ...          ...         ...        ...
# 70  157.341797  31.331587     80    248   981.668335  143.968750  25.747705
# 71  159.431641  31.349922     88    248   982.817566  145.350586  25.888737
# 72  158.363281  30.182920     80    248   911.008667  147.278320  24.634966
# 73  149.947266  28.292921     72    248   800.489380  144.090820  23.408806
# 74  150.589844  26.907461     72    248   724.011475  145.157227  23.241611
#
# ...

# %%
mean1, std1, min1, max1, var1 = conver(image_dataset_3,0)
mean2, std2, min2, max2, var2 = conver(image_dataset_3,1)
mean3, std3, min3, max3, var3 = conver(image_dataset_3,2)

mean4, std4, min4, max4, var4 = conver(HSV_dataset_3,0)
mean5, std5, min5, max5, var5 = conver(HSV_dataset_3,1)
mean6, std6, min6, max6, var6 = conver(HSV_dataset_3,2)

mean7, std7, min7, max7, var7 = conver(LAB_dataset_3,0)
mean8, std8, min8, max8, var8 = conver(LAB_dataset_3,1)
mean9, std9, min9, max9, var9 = conver(LAB_dataset_3,2)

# %%
cl3_df = pd.DataFrame()

# %%
cl3_df['mean_r'] = mean1
cl3_df['std_r'] = std1 
cl3_df['min_r'] = min1
cl3_df['max_r'] = max1
cl3_df['var_r'] = var1

cl3_df['mean_g'] = mean2
cl3_df['std_g'] = std2
cl3_df['min_g'] = min2
cl3_df['max_g'] = max2
cl3_df['var_g'] = var2

cl3_df['mean_b'] = mean3
cl3_df['std_b'] = std3
cl3_df['min_b'] = min3
cl3_df['max_b'] = max3
cl3_df['var_b'] = var3

cl3_df['mean_h'] = mean4
cl3_df['std_h'] = std4 
cl3_df['min_h'] = min4
cl3_df['max_h'] = max4
cl3_df['var_h'] = var4

cl3_df['mean_s'] = mean5
cl3_df['std_s'] = std5
cl3_df['min_s'] = min5
cl3_df['max_s'] = max5
cl3_df['var_s'] = var5

cl3_df['mean_v'] = mean6
cl3_df['std_v'] = std6
cl3_df['min_v'] = min6
cl3_df['max_v'] = max6
cl3_df['var_v'] = var6

cl3_df['mean_v'] = mean6
cl3_df['std_v'] = std6
cl3_df['min_v'] = min6
cl3_df['max_v'] = max6
cl3_df['var_v'] = var6

cl3_df['mean_l'] = mean7
cl3_df['std_l'] = std7
cl3_df['min_l'] = min7
cl3_df['max_l'] = max7
cl3_df['var_l'] = var7

cl3_df['mean_a'] = mean8
cl3_df['std_a'] = std8
cl3_df['min_a'] = min8
cl3_df['max_a'] = max8
cl3_df['var_a'] = var8

cl3_df['mean_b1'] = mean9
cl3_df['std_b1'] = std9
cl3_df['min_b1'] = min9
cl3_df['max_b1'] = max9
cl3_df['var_b1'] = var9

cl3_df
# Out:
#         mean_r      std_r  min_r  max_r       var_r      mean_g      std_g  \
# 0   176.843750  24.729296     80    248  611.538086  168.363281  27.302431
# 1   160.548828  24.135593     72    248  582.526917  152.711914  24.809528
# 2   156.156250  23.321274     80    248  543.881836  147.422852  23.263247
# 3   162.699219  24.969265     80    248  623.464233  153.264648  23.537832
# 4   162.876953  23.860035     64    248  569.301270  153.844727  24.476538
# ..         ...        ...    ...    ...         ...         ...        ...
# 85  155.671875  24.369905     64    248  593.892334  147.833008  22.431133
# 86  154.464844  24.115339     64    248  581.549561  147.209961  22.529079
# 87  152.601562  23.738432     56    248  563.513123  145.503906  22.338045
# 88  155.453125  23.785126     64    248  565.732178  148.300781  22.875242
# 89  155.214844  23.677702     64    248  560.633545  148.280273  22.933233
#
# ...

# %%
cl3_df ['Target'] = 2
cl3_df
# Out:
#         mean_r      std_r  min_r  max_r       var_r      mean_g      std_g  \
# 0   176.843750  24.729296     80    248  611.538086  168.363281  27.302431
# 1   160.548828  24.135593     72    248  582.526917  152.711914  24.809528
# 2   156.156250  23.321274     80    248  543.881836  147.422852  23.263247
# 3   162.699219  24.969265     80    248  623.464233  153.264648  23.537832
# 4   162.876953  23.860035     64    248  569.301270  153.844727  24.476538
# ..         ...        ...    ...    ...         ...         ...        ...
# 85  155.671875  24.369905     64    248  593.892334  147.833008  22.431133
# 86  154.464844  24.115339     64    248  581.549561  147.209961  22.529079
# 87  152.601562  23.738432     56    248  563.513123  145.503906  22.338045
# 88  155.453125  23.785126     64    248  565.732178  148.300781  22.875242
# 89  155.214844  23.677702     64    248  560.633545  148.280273  22.933233
#
# ...

# %%
mean1, std1, min1, max1, var1 = conver(image_dataset_4,0)
mean2, std2, min2, max2, var2 = conver(image_dataset_4,1)
mean3, std3, min3, max3, var3 = conver(image_dataset_4,2)

mean4, std4, min4, max4, var4 = conver(HSV_dataset_4,0)
mean5, std5, min5, max5, var5 = conver(HSV_dataset_4,1)
mean6, std6, min6, max6, var6 = conver(HSV_dataset_4,2)

mean7, std7, min7, max7, var7 = conver(LAB_dataset_4,0)
mean8, std8, min8, max8, var8 = conver(LAB_dataset_4,1)
mean9, std9, min9, max9, var9 = conver(LAB_dataset_4,2)

# %%
cl4_df = pd.DataFrame()

# %%
cl4_df['mean_r'] = mean1
cl4_df['std_r'] = std1 
cl4_df['min_r'] = min1
cl4_df['max_r'] = max1
cl4_df['var_r'] = var1

cl4_df['mean_g'] = mean2
cl4_df['std_g'] = std2
cl4_df['min_g'] = min2
cl4_df['max_g'] = max2
cl4_df['var_g'] = var2

cl4_df['mean_b'] = mean3
cl4_df['std_b'] = std3
cl4_df['min_b'] = min3
cl4_df['max_b'] = max3
cl4_df['var_b'] = var3

cl4_df['mean_h'] = mean4
cl4_df['std_h'] = std4 
cl4_df['min_h'] = min4
cl4_df['max_h'] = max4
cl4_df['var_h'] = var4

cl4_df['mean_s'] = mean5
cl4_df['std_s'] = std5
cl4_df['min_s'] = min5
cl4_df['max_s'] = max5
cl4_df['var_s'] = var5

cl4_df['mean_v'] = mean6
cl4_df['std_v'] = std6
cl4_df['min_v'] = min6
cl4_df['max_v'] = max6
cl4_df['var_v'] = var6

cl4_df['mean_v'] = mean6
cl4_df['std_v'] = std6
cl4_df['min_v'] = min6
cl4_df['max_v'] = max6
cl4_df['var_v'] = var6

cl4_df['mean_l'] = mean7
cl4_df['std_l'] = std7
cl4_df['min_l'] = min7
cl4_df['max_l'] = max7
cl4_df['var_l'] = var7

cl4_df['mean_a'] = mean8
cl4_df['std_a'] = std8
cl4_df['min_a'] = min8
cl4_df['max_a'] = max8
cl4_df['var_a'] = var8

cl4_df['mean_b1'] = mean9
cl4_df['std_b1'] = std9
cl4_df['min_b1'] = min9
cl4_df['max_b1'] = max9
cl4_df['var_b1'] = var9

cl4_df
# Out:
#         mean_r      std_r  min_r  max_r        var_r      mean_g      std_g  \
# 0   192.412109  25.458954     88    248   648.158264  183.951172  29.320387
# 1   160.886719  23.695227     64    248   561.463745  152.597656  25.306755
# 2   160.765625  23.179491     64    248   537.288818  152.340820  25.393255
# 3   179.335938  33.183151     80    248  1101.121582  168.407227  37.508049
# 4   159.574219  22.413862     64    248   502.381226  150.654297  24.882254
# ..         ...        ...    ...    ...          ...         ...        ...
# 77  157.707031  23.224283     64    248   539.367310  153.426758  24.525169
# 78  155.298828  23.226646     64    248   539.477112  151.574219  24.228855
# 79  149.429688  22.647152     56    248   512.893494  146.833984  23.785168
# 80  151.115234  22.891354     56    248   524.014038  148.599609  24.030088
# 81  156.109375  22.796392     72    248   519.675537  146.357422  23.064896
#
# ...

# %%
cl4_df ['Target'] = 3
cl4_df
# Out:
#         mean_r      std_r  min_r  max_r        var_r      mean_g      std_g  \
# 0   192.412109  25.458954     88    248   648.158264  183.951172  29.320387
# 1   160.886719  23.695227     64    248   561.463745  152.597656  25.306755
# 2   160.765625  23.179491     64    248   537.288818  152.340820  25.393255
# 3   179.335938  33.183151     80    248  1101.121582  168.407227  37.508049
# 4   159.574219  22.413862     64    248   502.381226  150.654297  24.882254
# ..         ...        ...    ...    ...          ...         ...        ...
# 77  157.707031  23.224283     64    248   539.367310  153.426758  24.525169
# 78  155.298828  23.226646     64    248   539.477112  151.574219  24.228855
# 79  149.429688  22.647152     56    248   512.893494  146.833984  23.785168
# 80  151.115234  22.891354     56    248   524.014038  148.599609  24.030088
# 81  156.109375  22.796392     72    248   519.675537  146.357422  23.064896
#
# ...

# %%
rhl = np.concatenate((cl1_df, cl2_df, cl3_df, cl4_df),axis=0)
rhl = pd.DataFrame(rhl,columns=['mean_r','std_r', 'min_r','max_r','var_r','mean_g','std_g', 'min_g','max_g','var_g','mean_b','std_b', 'min_b','max_b','var_b', 'mean_h','std_h', 'min_h','max_h','var_h','mean_s','std_s', 'min_s','max_s','var_s','mean_v','std_v', 'min_v','max_v','var_v', 'mean_l','std_l', 'min_l','max_l','var_l','mean_a','std_a', 'min_a','max_a','var_a','mean_b1','std_b1', 'min_b1','max_b1','var_b1','Target'])
rhl
# Out:
#          mean_r      std_r  min_r  max_r        var_r      mean_g      std_g  \
# 0    193.134766  39.782333   88.0  248.0  1582.634155  171.823242  35.688812
# 1    193.628906  39.693394   80.0  248.0  1575.565430  171.774414  35.723545
# 2    185.572266  37.156509   80.0  248.0  1380.606079  171.995117  33.045601
# 3    193.136719  41.929501   40.0  248.0  1758.082886  170.148438  37.029568
# 4    194.707031  38.719547   88.0  248.0  1499.203247  171.323242  35.665424
# ..          ...        ...    ...    ...          ...         ...        ...
# 302  157.707031  23.224283   64.0  248.0   539.367310  153.426758  24.525169
# 303  155.298828  23.226646   64.0  248.0   539.477112  151.574219  24.228855
# 304  149.429688  22.647152   56.0  248.0   512.893494  146.833984  23.785168
# 305  151.115234  22.891354   56.0  248.0   524.014038  148.599609  24.030088
# 306  156.109375  22.796392   72.0  248.0   519.675537  146.357422  23.064896
#
# ...

# %%
rhl.to_csv('3_channel_4_class_meregd.csv')
