# %%
# New dataset with QAT + Entire pipeline 
# Input: Image
# Output: CSV + model fitting + QAT modelling + TFLite file

# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import MinMaxScaler
import cv2
import os
import matplotlib
from skimage import color

# %% [markdown]
# ### Loading all the images

# %%
# Loading all the ppm day_1 images in an array
path_day_1 = '../Datasets/Phase_2_dataset/Day_1/PPMS'
day_1_images = []
for ind, i in enumerate(os.listdir(path_day_1)):
    day_1_images.append(cv2.cvtColor(cv2.imread(path_day_1+'/'+i),cv2.COLOR_BGR2RGB))
day_1_images = np.array(day_1_images)
day_1_images.shape
# Out:
# (111, 64, 64, 3)

# %%
# Loading all the ppm day_2 images in an array
path_day_2 = '../Datasets/Phase_2_dataset/Day_2/PPMS'
day_2_images = []
for ind, i in enumerate(os.listdir(path_day_2)):
    day_2_images.append(cv2.cvtColor(cv2.imread(path_day_2+'/'+i),cv2.COLOR_BGR2RGB))
day_2_images = np.array(day_2_images)
day_2_images.shape
# Out:
# (150, 64, 64, 3)

# %%
# Loading all the ppm day_3 images in an array
path_day_3 = '../Datasets/Phase_2_dataset/Day_3/PPMS'
day_3_images = []
for ind, i in enumerate(os.listdir(path_day_3)):
    day_3_images.append(cv2.cvtColor(cv2.imread(path_day_3+'/'+i),cv2.COLOR_BGR2RGB))
day_3_images = np.array(day_3_images)
day_3_images.shape
# Out:
# (188, 64, 64, 3)

# %% [markdown]
# ### Making HSV images

# %%
# Converting all day_1 images into HSV
hsv_day_1_images = []
for i in day_1_images:
    hsv_day_1_images.append(matplotlib.colors.rgb_to_hsv(i))
hsv_day_1_images = np.array(hsv_day_1_images)
hsv_day_1_images.shape
# Out:
# (111, 64, 64, 3)

# %%
# Converting all day_2 images into HSV
hsv_day_2_images = []
for i in day_2_images:
    hsv_day_2_images.append(matplotlib.colors.rgb_to_hsv(i))
hsv_day_2_images = np.array(hsv_day_2_images)
hsv_day_2_images.shape
# Out:
# (150, 64, 64, 3)

# %%
# Converting all day_3 images into HSV
hsv_day_3_images = []
for i in day_3_images:
    hsv_day_3_images.append(matplotlib.colors.rgb_to_hsv(i))
hsv_day_3_images = np.array(hsv_day_3_images)
hsv_day_3_images.shape
# Out:
# (188, 64, 64, 3)

# %% [markdown]
# ### Making LAB images

# %%
# Converting all day_1 images into LAB
lab_day_1_images = []
for i in day_1_images:
    lab_day_1_images.append(color.rgb2lab(i))
lab_day_1_images = np.array(lab_day_1_images)
lab_day_1_images.shape
# Out:
# (111, 64, 64, 3)

# %%
# Converting all day_2 images into LAB
lab_day_2_images = []
for i in day_2_images:
    lab_day_2_images.append(color.rgb2lab(i))
lab_day_2_images = np.array(lab_day_2_images)
lab_day_2_images.shape
# Out:
# (150, 64, 64, 3)

# %%
# Converting all day_1 images into LAB
lab_day_3_images = []
for i in day_3_images:
    lab_day_3_images.append(color.rgb2lab(i))
lab_day_3_images = np.array(lab_day_3_images)
lab_day_3_images.shape
# Out:
# (188, 64, 64, 3)

# %% [markdown]
# ### Random images generation

# %%
# Day 1 images
fig, axs = plt.subplots(1, 3)
r_ind = np.random.randint(day_1_images.shape[0])
# Display each image in a separate subplot
axs[0].imshow(day_1_images[r_ind])
axs[0].set_title('RGB')
axs[1].imshow(hsv_day_1_images[r_ind])
axs[1].set_title('HSV')
axs[2].imshow(lab_day_1_images[r_ind])
axs[2].set_title('LAB')

# Show the plot
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# Day 2 images
fig, axs = plt.subplots(1, 3)
r_ind = np.random.randint(day_2_images.shape[0])
# Display each image in a separate subplot
axs[0].imshow(day_2_images[r_ind])
axs[0].set_title('RGB')
axs[1].imshow(hsv_day_2_images[r_ind])
axs[1].set_title('HSV')
axs[2].imshow(lab_day_2_images[r_ind])
axs[2].set_title('LAB')

# Show the plot
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# Day 3 images
# Day 1 images
fig, axs = plt.subplots(1, 3)
r_ind = np.random.randint(day_3_images.shape[0])
# Display each image in a separate subplot
axs[0].imshow(day_3_images[r_ind])
axs[0].set_title('RGB')
axs[1].imshow(hsv_day_3_images[r_ind])
axs[1].set_title('HSV')
axs[2].imshow(lab_day_3_images[r_ind])
axs[2].set_title('LAB')

# Show the plot
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ### Making the CSV files

# %%
def conver(class123,channel):
    meanlist = []
    stdlist = []
    minlist = []
    maxlist = []
    varlist = []
    for i in range(class123.shape[0]):
        meanlist.append(np.mean(class123[i,:,:,channel])),
        stdlist.append(np.std(class123[i,:,:,channel])),
        minlist.append(np.min(class123[i,:,:,channel])),
        maxlist.append(np.max(class123[i,:,:,channel])),
        varlist.append(np.var(class123[i,:,:,channel])),
    meanlist = np.array(meanlist,dtype='float32')
    stdlist = np.array(stdlist,dtype='float32')
    minlist = np.array(minlist,dtype='int32')
    maxlist = np.array(maxlist,dtype='int32')
    varlist = np.array(varlist,dtype='float32')
    return meanlist,stdlist,minlist,maxlist,varlist

# %%
mean1, std1, min1, max1, var1 = conver(day_1_images,0)
mean2, std2, min2, max2, var2 = conver(day_1_images,1)
mean3, std3, min3, max3, var3 = conver(day_1_images,2)

mean4, std4, min4, max4, var4 = conver(hsv_day_1_images,0)
mean5, std5, min5, max5, var5 = conver(hsv_day_1_images,1)
mean6, std6, min6, max6, var6 = conver(hsv_day_1_images,2)

mean7, std7, min7, max7, var7 = conver(lab_day_1_images,0)
mean8, std8, min8, max8, var8 = conver(lab_day_1_images,1)
mean9, std9, min9, max9, var9 = conver(lab_day_1_images,2)

# %%
cl1_df = pd.DataFrame()

# %%
cl1_df['mean_r'] = mean1
cl1_df['std_r'] = std1 
cl1_df['min_r'] = min1
cl1_df['max_r'] = max1
cl1_df['var_r'] = var1

cl1_df['mean_g'] = mean2
cl1_df['std_g'] = std2
cl1_df['min_g'] = min2
cl1_df['max_g'] = max2
cl1_df['var_g'] = var2

cl1_df['mean_b'] = mean3
cl1_df['std_b'] = std3
cl1_df['min_b'] = min3
cl1_df['max_b'] = max3
cl1_df['var_b'] = var3

cl1_df['mean_h'] = mean4
cl1_df['std_h'] = std4 
cl1_df['min_h'] = min4
cl1_df['max_h'] = max4
cl1_df['var_h'] = var4

cl1_df['mean_s'] = mean5
cl1_df['std_s'] = std5
cl1_df['min_s'] = min5
cl1_df['max_s'] = max5
cl1_df['var_s'] = var5

cl1_df['mean_v'] = mean6
cl1_df['std_v'] = std6
cl1_df['min_v'] = min6
cl1_df['max_v'] = max6
cl1_df['var_v'] = var6

cl1_df['mean_l'] = mean7
cl1_df['std_l'] = std7
cl1_df['min_l'] = min7
cl1_df['max_l'] = max7
cl1_df['var_l'] = var7

cl1_df['mean_a'] = mean8
cl1_df['std_a'] = std8
cl1_df['min_a'] = min8
cl1_df['max_a'] = max8
cl1_df['var_a'] = var8

cl1_df['mean_b1'] = mean9
cl1_df['std_b1'] = std9
cl1_df['min_b1'] = min9
cl1_df['max_b1'] = max9
cl1_df['var_b1'] = var9

cl1_df
# Out:
#          mean_r      std_r  min_r  max_r       var_r      mean_g      std_g  \
# 0    247.068359   7.415620    128    248   54.991421  248.497070  12.394516
# 1    247.849609   1.487198    216    248    2.211758  250.097656   6.781627
# 2    247.878906   1.268990    224    248    1.610336  250.358398   6.200150
# 3    247.896484   1.226748    216    248    1.504910  250.635742   5.571458
# 4    247.916016   1.064693    216    248    1.133572  250.876953   4.936758
# ..          ...        ...    ...    ...         ...         ...        ...
# 106  220.408203  23.251793    144    248  540.645874  183.434570  25.748266
# 107  219.257812  24.460026    136    248  598.292908  181.778320  27.255548
# 108  213.755859  26.778807    136    248  717.104431  175.222656  26.573696
# 109  207.263672  28.742472    128    248  826.129700  169.047852  26.296232
# 110  204.960938  28.933897    120    248  837.170349  167.765625  26.326670
#
#      min_g  max_g       var_g  ...     mean_a      std_a  min_a  max_a  \
# 0       92    252  153.624008  ...  -4.318130   4.506680    -18     25
# 1      184    252   45.990463  ...  -4.376608   3.927215    -19     18
# 2      188    252   38.441864  ...  -4.338687   3.725428    -19     17
# 3      188    252   31.041145  ...  -4.352789   3.622292    -19     15
# 4      192    252   24.371578  ...  -4.257624   3.443273    -18     14
# ..     ...    ...         ...  ...        ...        ...    ...    ...
# 106     88    252  662.973267  ...  12.132936  12.784688    -16     57
# 107     88    252  742.864929  ...  12.425775  13.055315    -16     58
# 108     84    252  706.161377  ...  13.282067  13.660368    -16     60
# 109     84    252  691.491821  ...  13.931546  14.369800    -15     58
# 110     80    252  693.093506  ...  13.859297  14.568910    -13     59
#
#           var_a    mean_b1     std_b1  min_b1  max_b1      var_b1
# 0     20.310160  11.873751  13.650517     -17      68  186.336624
# 1     15.423016  10.871710  12.343535      -5      65  152.362885
# 2     13.878817  10.415691  11.806664      -4      65  139.397308
# 3     13.120997  10.122630  11.616109      -5      65  134.933975
# 4     11.856128   9.511590  11.032106      -4      61  121.707367
# ..          ...        ...        ...     ...     ...         ...
# 106  163.448242  12.790504  17.196478      -7      68  295.718842
# 107  170.441254  12.679663  17.209827      -7      66  296.178131
# 108  186.605667  11.801290  17.564184      -8      68  308.500580
# 109  206.491135   9.732851  17.607370      -9      65  310.019531
# 110  212.253128   8.708740  17.412096      -9      63  303.181091
#
# [111 rows x 45 columns]

# %%
cl1_df ['Target'] = 0
cl1_df
# Out:
#          mean_r      std_r  min_r  max_r       var_r      mean_g      std_g  \
# 0    247.068359   7.415620    128    248   54.991421  248.497070  12.394516
# 1    247.849609   1.487198    216    248    2.211758  250.097656   6.781627
# 2    247.878906   1.268990    224    248    1.610336  250.358398   6.200150
# 3    247.896484   1.226748    216    248    1.504910  250.635742   5.571458
# 4    247.916016   1.064693    216    248    1.133572  250.876953   4.936758
# ..          ...        ...    ...    ...         ...         ...        ...
# 106  220.408203  23.251793    144    248  540.645874  183.434570  25.748266
# 107  219.257812  24.460026    136    248  598.292908  181.778320  27.255548
# 108  213.755859  26.778807    136    248  717.104431  175.222656  26.573696
# 109  207.263672  28.742472    128    248  826.129700  169.047852  26.296232
# 110  204.960938  28.933897    120    248  837.170349  167.765625  26.326670
#
#      min_g  max_g       var_g  ...      std_a  min_a  max_a       var_a  \
# 0       92    252  153.624008  ...   4.506680    -18     25   20.310160
# 1      184    252   45.990463  ...   3.927215    -19     18   15.423016
# 2      188    252   38.441864  ...   3.725428    -19     17   13.878817
# 3      188    252   31.041145  ...   3.622292    -19     15   13.120997
# 4      192    252   24.371578  ...   3.443273    -18     14   11.856128
# ..     ...    ...         ...  ...        ...    ...    ...         ...
# 106     88    252  662.973267  ...  12.784688    -16     57  163.448242
# 107     88    252  742.864929  ...  13.055315    -16     58  170.441254
# 108     84    252  706.161377  ...  13.660368    -16     60  186.605667
# 109     84    252  691.491821  ...  14.369800    -15     58  206.491135
# 110     80    252  693.093506  ...  14.568910    -13     59  212.253128
#
#        mean_b1     std_b1  min_b1  max_b1      var_b1  Target
# 0    11.873751  13.650517     -17      68  186.336624       0
# 1    10.871710  12.343535      -5      65  152.362885       0
# 2    10.415691  11.806664      -4      65  139.397308       0
# 3    10.122630  11.616109      -5      65  134.933975       0
# 4     9.511590  11.032106      -4      61  121.707367       0
# ..         ...        ...     ...     ...         ...     ...
# 106  12.790504  17.196478      -7      68  295.718842       0
# 107  12.679663  17.209827      -7      66  296.178131       0
# 108  11.801290  17.564184      -8      68  308.500580       0
# 109   9.732851  17.607370      -9      65  310.019531       0
# 110   8.708740  17.412096      -9      63  303.181091       0
#
# [111 rows x 46 columns]

# %%
mean1, std1, min1, max1, var1 = conver(day_2_images,0)
mean2, std2, min2, max2, var2 = conver(day_2_images,1)
mean3, std3, min3, max3, var3 = conver(day_2_images,2)

mean4, std4, min4, max4, var4 = conver(hsv_day_2_images,0)
mean5, std5, min5, max5, var5 = conver(hsv_day_2_images,1)
mean6, std6, min6, max6, var6 = conver(hsv_day_2_images,2)

mean7, std7, min7, max7, var7 = conver(lab_day_2_images,0)
mean8, std8, min8, max8, var8 = conver(lab_day_2_images,1)
mean9, std9, min9, max9, var9 = conver(lab_day_2_images,2)

# %%
cl2_df = pd.DataFrame()

# %%
cl2_df['mean_r'] = mean1
cl2_df['std_r'] = std1 
cl2_df['min_r'] = min1
cl2_df['max_r'] = max1
cl2_df['var_r'] = var1

cl2_df['mean_g'] = mean2
cl2_df['std_g'] = std2
cl2_df['min_g'] = min2
cl2_df['max_g'] = max2
cl2_df['var_g'] = var2

cl2_df['mean_b'] = mean3
cl2_df['std_b'] = std3
cl2_df['min_b'] = min3
cl2_df['max_b'] = max3
cl2_df['var_b'] = var3

cl2_df['mean_h'] = mean4
cl2_df['std_h'] = std4 
cl2_df['min_h'] = min4
cl2_df['max_h'] = max4
cl2_df['var_h'] = var4

cl2_df['mean_s'] = mean5
cl2_df['std_s'] = std5
cl2_df['min_s'] = min5
cl2_df['max_s'] = max5
cl2_df['var_s'] = var5

cl2_df['mean_v'] = mean6
cl2_df['std_v'] = std6
cl2_df['min_v'] = min6
cl2_df['max_v'] = max6
cl2_df['var_v'] = var6

cl2_df['mean_l'] = mean7
cl2_df['std_l'] = std7
cl2_df['min_l'] = min7
cl2_df['max_l'] = max7
cl2_df['var_l'] = var7

cl2_df['mean_a'] = mean8
cl2_df['std_a'] = std8
cl2_df['min_a'] = min8
cl2_df['max_a'] = max8
cl2_df['var_a'] = var8

cl2_df['mean_b1'] = mean9
cl2_df['std_b1'] = std9
cl2_df['min_b1'] = min9
cl2_df['max_b1'] = max9
cl2_df['var_b1'] = var9

cl2_df
# Out:
#          mean_r      std_r  min_r  max_r       var_r      mean_g      std_g  \
# 0    244.431641   9.246685    152    248   85.501190  235.170898  22.760044
# 1    245.498047   7.506638    160    248   56.349606  238.622070  19.627481
# 2    245.773438   7.166234    160    248   51.354919  239.349609  19.190422
# 3    246.216797   6.532959    160    248   42.679562  241.201172  17.948345
# 4    246.466797   6.114218    168    248   37.383663  242.205078  17.217728
# ..          ...        ...    ...    ...         ...         ...        ...
# 145   65.759766  15.305639     16    160  234.262604   68.844727  13.681124
# 146   47.103516  12.537172      8    128  157.180695   46.794922  11.426093
# 147   25.525391   9.136195      0     88   83.470062   24.442383   8.034812
# 148   24.244141   4.277823     16     64   18.299770   23.454102   3.592913
# 149   17.220703   2.946482     16     40    8.681759   20.351562   1.355486
#
#      min_g  max_g       var_g  ...    mean_a     std_a  min_a  max_a  \
# 0      116    252  518.019592  ...  1.927100  7.339437    -16     49
# 1      128    252  385.238037  ...  0.995445  6.380447    -16     44
# 2      128    252  368.272308  ...  0.767245  6.210449    -15     44
# 3      132    252  322.143127  ...  0.240578  5.790886    -17     43
# 4      132    252  296.450134  ... -0.016780  5.577125    -17     44
# ..     ...    ...         ...  ...       ...       ...    ...    ...
# 145     16    164  187.173157  ...  1.951950  7.426554     -9     29
# 146      4    124  130.555603  ...  2.832929  6.416898     -6     29
# 147      0     88   64.558205  ...  2.261461  4.374535     -3     22
# 148     16     60   12.909026  ...  0.670630  2.142695     -6     12
# 149     16     36    1.837341  ... -1.957191  1.130574     -5      3
#
#          var_a   mean_b1     std_b1  min_b1  max_b1      var_b1
# 0    53.867344  5.999698  10.697090      -7      54  114.427734
# 1    40.710106  5.789333  10.304381      -7      58  106.180275
# 2    38.569679  5.906173  10.211851      -7      54  104.281906
# 3    33.534363  5.731565   9.850948      -5      57   97.041176
# 4    31.104321  5.555195   9.506277      -6      54   90.369301
# ..         ...       ...        ...     ...     ...         ...
# 145  55.153698 -5.881501   7.566823     -16      22   57.256817
# 146  41.176579 -4.581858   6.705154     -12      23   44.959091
# 147  19.136559 -3.410695   4.795624     -11      18   22.998007
# 148   4.591143 -0.464677   2.172979      -6      10    4.721837
# 149   1.278198  1.617443   0.723283      -3       5    0.523139
#
# [150 rows x 45 columns]

# %%
cl2_df ['Target'] = 1
cl2_df
# Out:
#          mean_r      std_r  min_r  max_r       var_r      mean_g      std_g  \
# 0    244.431641   9.246685    152    248   85.501190  235.170898  22.760044
# 1    245.498047   7.506638    160    248   56.349606  238.622070  19.627481
# 2    245.773438   7.166234    160    248   51.354919  239.349609  19.190422
# 3    246.216797   6.532959    160    248   42.679562  241.201172  17.948345
# 4    246.466797   6.114218    168    248   37.383663  242.205078  17.217728
# ..          ...        ...    ...    ...         ...         ...        ...
# 145   65.759766  15.305639     16    160  234.262604   68.844727  13.681124
# 146   47.103516  12.537172      8    128  157.180695   46.794922  11.426093
# 147   25.525391   9.136195      0     88   83.470062   24.442383   8.034812
# 148   24.244141   4.277823     16     64   18.299770   23.454102   3.592913
# 149   17.220703   2.946482     16     40    8.681759   20.351562   1.355486
#
#      min_g  max_g       var_g  ...     std_a  min_a  max_a      var_a  \
# 0      116    252  518.019592  ...  7.339437    -16     49  53.867344
# 1      128    252  385.238037  ...  6.380447    -16     44  40.710106
# 2      128    252  368.272308  ...  6.210449    -15     44  38.569679
# 3      132    252  322.143127  ...  5.790886    -17     43  33.534363
# 4      132    252  296.450134  ...  5.577125    -17     44  31.104321
# ..     ...    ...         ...  ...       ...    ...    ...        ...
# 145     16    164  187.173157  ...  7.426554     -9     29  55.153698
# 146      4    124  130.555603  ...  6.416898     -6     29  41.176579
# 147      0     88   64.558205  ...  4.374535     -3     22  19.136559
# 148     16     60   12.909026  ...  2.142695     -6     12   4.591143
# 149     16     36    1.837341  ...  1.130574     -5      3   1.278198
#
#       mean_b1     std_b1  min_b1  max_b1      var_b1  Target
# 0    5.999698  10.697090      -7      54  114.427734       1
# 1    5.789333  10.304381      -7      58  106.180275       1
# 2    5.906173  10.211851      -7      54  104.281906       1
# 3    5.731565   9.850948      -5      57   97.041176       1
# 4    5.555195   9.506277      -6      54   90.369301       1
# ..        ...        ...     ...     ...         ...     ...
# 145 -5.881501   7.566823     -16      22   57.256817       1
# 146 -4.581858   6.705154     -12      23   44.959091       1
# 147 -3.410695   4.795624     -11      18   22.998007       1
# 148 -0.464677   2.172979      -6      10    4.721837       1
# 149  1.617443   0.723283      -3       5    0.523139       1
#
# [150 rows x 46 columns]

# %%
mean1, std1, min1, max1, var1 = conver(day_3_images,0)
mean2, std2, min2, max2, var2 = conver(day_3_images,1)
mean3, std3, min3, max3, var3 = conver(day_3_images,2)

mean4, std4, min4, max4, var4 = conver(hsv_day_3_images,0)
mean5, std5, min5, max5, var5 = conver(hsv_day_3_images,1)
mean6, std6, min6, max6, var6 = conver(hsv_day_3_images,2)

mean7, std7, min7, max7, var7 = conver(lab_day_3_images,0)
mean8, std8, min8, max8, var8 = conver(lab_day_3_images,1)
mean9, std9, min9, max9, var9 = conver(lab_day_3_images,2)

# %%
cl3_df = pd.DataFrame()

# %%
cl3_df['mean_r'] = mean1
cl3_df['std_r'] = std1 
cl3_df['min_r'] = min1
cl3_df['max_r'] = max1
cl3_df['var_r'] = var1

cl3_df['mean_g'] = mean2
cl3_df['std_g'] = std2
cl3_df['min_g'] = min2
cl3_df['max_g'] = max2
cl3_df['var_g'] = var2

cl3_df['mean_b'] = mean3
cl3_df['std_b'] = std3
cl3_df['min_b'] = min3
cl3_df['max_b'] = max3
cl3_df['var_b'] = var3

cl3_df['mean_h'] = mean4
cl3_df['std_h'] = std4 
cl3_df['min_h'] = min4
cl3_df['max_h'] = max4
cl3_df['var_h'] = var4

cl3_df['mean_s'] = mean5
cl3_df['std_s'] = std5
cl3_df['min_s'] = min5
cl3_df['max_s'] = max5
cl3_df['var_s'] = var5

cl3_df['mean_v'] = mean6
cl3_df['std_v'] = std6
cl3_df['min_v'] = min6
cl3_df['max_v'] = max6
cl3_df['var_v'] = var6

cl3_df['mean_v'] = mean6
cl3_df['std_v'] = std6
cl3_df['min_v'] = min6
cl3_df['max_v'] = max6
cl3_df['var_v'] = var6

cl3_df['mean_l'] = mean7
cl3_df['std_l'] = std7
cl3_df['min_l'] = min7
cl3_df['max_l'] = max7
cl3_df['var_l'] = var7

cl3_df['mean_a'] = mean8
cl3_df['std_a'] = std8
cl3_df['min_a'] = min8
cl3_df['max_a'] = max8
cl3_df['var_a'] = var8

cl3_df['mean_b1'] = mean9
cl3_df['std_b1'] = std9
cl3_df['min_b1'] = min9
cl3_df['max_b1'] = max9
cl3_df['var_b1'] = var9

cl3_df
# Out:
#          mean_r      std_r  min_r  max_r       var_r      mean_g      std_g  \
# 0     16.496094   2.031967     16     40    4.128891   20.203125   1.333811
# 1     25.121094   3.656248     16     64   13.368149   26.753906   3.319271
# 2     22.298828   9.050021      0     96   81.902893   23.212891   8.161791
# 3     43.050781  11.906100      8    136  141.755234   45.270508  11.608484
# 4     61.988281  15.239234     16    176  232.234238   67.324219  14.039160
# ..          ...        ...    ...    ...         ...         ...        ...
# 183  185.318359  26.553532     88    248  705.090027  164.212891  25.057777
# 184  180.847656  25.903671     88    248  671.000244  162.835938  25.046450
# 185  176.138672  25.751144     80    248  663.121399  160.673828  25.112385
# 186  171.228516  25.513449     72    248  650.936035  157.438477  24.809689
# 187  165.847656  25.348051     72    248  642.523682  154.046875  24.372391
#
#      min_g  max_g       var_g  ...    mean_a      std_a  min_a  max_a  \
# 0       16     36    1.779053  ... -2.220038   0.970528     -5      3
# 1       20     60   11.017563  ... -0.413697   1.879925     -5     10
# 2        0     88   66.614838  ...  1.729865   3.834764     -5     18
# 3        8    128  134.756897  ...  1.941425   5.892717     -6     28
# 4       16    168  197.098007  ...  1.560529   7.047499     -6     29
# ..     ...    ...         ...  ...       ...        ...    ...    ...
# 183     72    252  627.892151  ...  8.400492  11.670238    -12     47
# 184     64    252  627.324646  ...  7.729246  11.307699    -11     45
# 185     64    252  630.631897  ...  7.169503  11.131242    -16     47
# 186     64    252  615.520630  ...  6.856700  10.946127    -15     44
# 187     64    252  594.013428  ...  6.466043  10.813241    -13     43
#
#           var_a   mean_b1     std_b1  min_b1  max_b1      var_b1
# 0      0.941925  1.582374   0.972625      -3       4    0.945999
# 1      3.534118 -0.963364   2.272755      -5       8    5.165417
# 2     14.705416 -4.477213   4.947777     -12      15   24.480495
# 3     34.724113 -5.260230   6.499729     -15      22   42.246471
# 4     49.667248 -7.079423   7.713660     -16      22   59.500557
# ..          ...       ...        ...     ...     ...         ...
# 183  136.194443  3.528605  12.267705      -9      53  150.496582
# 184  127.864052  1.812102  12.047604     -10      49  145.144760
# 185  123.904541  0.478765  11.825370     -13      49  139.839371
# 186  119.817703 -0.504751  11.676307     -13      48  136.336136
# 187  116.926193 -1.570303  11.607977     -16      48  134.745132
#
# [188 rows x 45 columns]

# %%
cl3_df ['Target'] = 2
cl3_df
# Out:
#          mean_r      std_r  min_r  max_r       var_r      mean_g      std_g  \
# 0     16.496094   2.031967     16     40    4.128891   20.203125   1.333811
# 1     25.121094   3.656248     16     64   13.368149   26.753906   3.319271
# 2     22.298828   9.050021      0     96   81.902893   23.212891   8.161791
# 3     43.050781  11.906100      8    136  141.755234   45.270508  11.608484
# 4     61.988281  15.239234     16    176  232.234238   67.324219  14.039160
# ..          ...        ...    ...    ...         ...         ...        ...
# 183  185.318359  26.553532     88    248  705.090027  164.212891  25.057777
# 184  180.847656  25.903671     88    248  671.000244  162.835938  25.046450
# 185  176.138672  25.751144     80    248  663.121399  160.673828  25.112385
# 186  171.228516  25.513449     72    248  650.936035  157.438477  24.809689
# 187  165.847656  25.348051     72    248  642.523682  154.046875  24.372391
#
#      min_g  max_g       var_g  ...      std_a  min_a  max_a       var_a  \
# 0       16     36    1.779053  ...   0.970528     -5      3    0.941925
# 1       20     60   11.017563  ...   1.879925     -5     10    3.534118
# 2        0     88   66.614838  ...   3.834764     -5     18   14.705416
# 3        8    128  134.756897  ...   5.892717     -6     28   34.724113
# 4       16    168  197.098007  ...   7.047499     -6     29   49.667248
# ..     ...    ...         ...  ...        ...    ...    ...         ...
# 183     72    252  627.892151  ...  11.670238    -12     47  136.194443
# 184     64    252  627.324646  ...  11.307699    -11     45  127.864052
# 185     64    252  630.631897  ...  11.131242    -16     47  123.904541
# 186     64    252  615.520630  ...  10.946127    -15     44  119.817703
# 187     64    252  594.013428  ...  10.813241    -13     43  116.926193
#
#       mean_b1     std_b1  min_b1  max_b1      var_b1  Target
# 0    1.582374   0.972625      -3       4    0.945999       2
# 1   -0.963364   2.272755      -5       8    5.165417       2
# 2   -4.477213   4.947777     -12      15   24.480495       2
# 3   -5.260230   6.499729     -15      22   42.246471       2
# 4   -7.079423   7.713660     -16      22   59.500557       2
# ..        ...        ...     ...     ...         ...     ...
# 183  3.528605  12.267705      -9      53  150.496582       2
# 184  1.812102  12.047604     -10      49  145.144760       2
# 185  0.478765  11.825370     -13      49  139.839371       2
# 186 -0.504751  11.676307     -13      48  136.336136       2
# 187 -1.570303  11.607977     -16      48  134.745132       2
#
# [188 rows x 46 columns]

# %%
rhl = np.concatenate((cl1_df, cl2_df, cl3_df),axis=0)
rhl = pd.DataFrame(rhl,columns=['mean_r','std_r', 'min_r','max_r','var_r','mean_g','std_g', 'min_g','max_g','var_g','mean_b','std_b', 'min_b','max_b','var_b', 'mean_h','std_h', 'min_h','max_h','var_h','mean_s','std_s', 'min_s','max_s','var_s','mean_v','std_v', 'min_v','max_v','var_v', 'mean_l','std_l', 'min_l','max_l','var_l','mean_a','std_a', 'min_a','max_a','var_a','mean_b1','std_b1', 'min_b1','max_b1','var_b1','Target'])
rhl
# Out:
#          mean_r      std_r  min_r  max_r       var_r      mean_g      std_g  \
# 0    247.068359   7.415620  128.0  248.0   54.991421  248.497070  12.394516
# 1    247.849609   1.487198  216.0  248.0    2.211758  250.097656   6.781627
# 2    247.878906   1.268990  224.0  248.0    1.610336  250.358398   6.200150
# 3    247.896484   1.226748  216.0  248.0    1.504910  250.635742   5.571458
# 4    247.916016   1.064693  216.0  248.0    1.133572  250.876953   4.936758
# ..          ...        ...    ...    ...         ...         ...        ...
# 444  185.318359  26.553532   88.0  248.0  705.090027  164.212891  25.057777
# 445  180.847656  25.903671   88.0  248.0  671.000244  162.835938  25.046450
# 446  176.138672  25.751144   80.0  248.0  663.121399  160.673828  25.112385
# 447  171.228516  25.513449   72.0  248.0  650.936035  157.438477  24.809689
# 448  165.847656  25.348051   72.0  248.0  642.523682  154.046875  24.372391
#
#      min_g  max_g       var_g  ...      std_a  min_a  max_a       var_a  \
# 0     92.0  252.0  153.624008  ...   4.506680  -18.0   25.0   20.310160
# 1    184.0  252.0   45.990463  ...   3.927215  -19.0   18.0   15.423016
# 2    188.0  252.0   38.441864  ...   3.725428  -19.0   17.0   13.878817
# 3    188.0  252.0   31.041145  ...   3.622292  -19.0   15.0   13.120997
# 4    192.0  252.0   24.371578  ...   3.443273  -18.0   14.0   11.856128
# ..     ...    ...         ...  ...        ...    ...    ...         ...
# 444   72.0  252.0  627.892151  ...  11.670238  -12.0   47.0  136.194443
# 445   64.0  252.0  627.324646  ...  11.307699  -11.0   45.0  127.864052
# 446   64.0  252.0  630.631897  ...  11.131242  -16.0   47.0  123.904541
# 447   64.0  252.0  615.520630  ...  10.946127  -15.0   44.0  119.817703
# 448   64.0  252.0  594.013428  ...  10.813241  -13.0   43.0  116.926193
#
#        mean_b1     std_b1  min_b1  max_b1      var_b1  Target
# 0    11.873751  13.650517   -17.0    68.0  186.336624     0.0
# 1    10.871710  12.343535    -5.0    65.0  152.362885     0.0
# 2    10.415691  11.806664    -4.0    65.0  139.397308     0.0
# 3    10.122630  11.616109    -5.0    65.0  134.933975     0.0
# 4     9.511590  11.032106    -4.0    61.0  121.707367     0.0
# ..         ...        ...     ...     ...         ...     ...
# 444   3.528605  12.267705    -9.0    53.0  150.496582     2.0
# 445   1.812102  12.047604   -10.0    49.0  145.144760     2.0
# 446   0.478765  11.825370   -13.0    49.0  139.839371     2.0
# 447  -0.504751  11.676307   -13.0    48.0  136.336136     2.0
# 448  -1.570303  11.607977   -16.0    48.0  134.745132     2.0
#
# [449 rows x 46 columns]

# %%
# Saving the dataset 
rhl.to_csv("phase_2_rgbhsvlab_withoutbg.csv", index=False)

# %%
y = rhl['Target']

rhl.drop('Target', inplace=True, axis=1)

x = rhl
print(x.shape,y.shape)
# Out:
# (449, 45) (449,)

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2, random_state = 42)
print(x_train.shape,y_train.shape,x_test.shape,y_test.shape)
# Out:
# (359, 45) (359,) (90, 45) (90,)

# %%
# # x_test into a csv file
# x_test.to_csv('test_data_input.csv')
# y_test.to_csv('test_data_output.csv')

# %%
x_train
# Out:
#          mean_r      std_r  min_r  max_r       var_r      mean_g      std_g  \
# 17   247.974609   0.544270  232.0  248.0    0.296230  251.429688   3.600528
# 66   247.712891   2.324208  192.0  248.0    5.401943  248.041992   9.612116
# 176  247.738281   2.357224  200.0  248.0    5.556503  249.934570   7.448496
# 247  129.761719  24.667591   56.0  248.0  608.490112  121.415039  20.521179
# 31   247.962891   0.759439  224.0  248.0    0.576748  251.567383   2.648030
# ..          ...        ...    ...    ...         ...         ...        ...
# 106  220.408203  23.251793  144.0  248.0  540.645874  183.434570  25.748266
# 270  106.478516  21.213146   40.0  248.0  449.997589  105.868164  18.624533
# 348  247.558594   3.287120  192.0  248.0   10.805161  250.025391   7.572007
# 435  206.962891  25.230860  104.0  248.0  636.596252  182.044922  25.968992
# 102  221.468750  23.796644  144.0  248.0  566.280273  185.575195  26.135450
#
#      min_g  max_g       var_g  ...     mean_a      std_a  min_a  max_a  \
# 17   184.0  252.0   12.963806  ...  -3.311305   2.601172  -16.0   20.0
# 66   176.0  252.0   92.392769  ...  -3.012384   4.115195  -16.0   24.0
# 176  176.0  252.0   55.480095  ...  -2.139206   2.657902  -14.0   22.0
# 247   40.0  252.0  421.118744  ...   6.451426  10.770576   -6.0   45.0
# 31   208.0  252.0    7.012061  ...  -3.308691   2.455698  -15.0   12.0
# ..     ...    ...         ...  ...        ...        ...    ...    ...
# 106   88.0  252.0  662.973267  ...  12.132936  12.784688  -16.0   57.0
# 270   36.0  240.0  346.873230  ...   5.121629   8.664259   -5.0   35.0
# 348  168.0  252.0   57.335293  ...  -2.063532   2.417838  -14.0   27.0
# 435   84.0  252.0  674.388611  ...   8.724564  11.138253  -11.0   48.0
# 102   88.0  252.0  683.061707  ...  11.709312  12.497776  -17.0   55.0
#
#           var_a    mean_b1     std_b1  min_b1  max_b1      var_b1
# 17     6.766095   5.937703   8.090723    -5.0    58.0   65.459793
# 66    16.934830   9.030621  11.759205    -4.0    55.0  138.278900
# 176    7.064444   3.938843   6.452703    -3.0    42.0   41.637383
# 247  116.005310  -4.403704  11.853439   -18.0    43.0  140.504013
# 31     6.030451   5.726631   7.702614    -1.0    48.0   59.330269
# ..          ...        ...        ...     ...     ...         ...
# 106  163.448242  12.790504  17.196478    -7.0    68.0  295.718842
# 270   75.069389  -9.035880  10.842826   -21.0    31.0  117.566879
# 348    5.845942   3.371449   5.380074    -3.0    42.0   28.945189
# 435  124.060677   6.516893  12.442735    -9.0    55.0  154.821640
# 102  156.194397  12.686707  17.970125    -8.0    67.0  322.925415
#
# [359 rows x 45 columns]

# %%
scaler = MinMaxScaler()
scaler.fit(x_train)
x_train = scaler.transform(x_train)
x_test = scaler.transform(x_test)

# %%
x_train
# Out:
# array([[9.99991536e-01, 5.09030199e-04, 1.00000000e+00, ...,
#         7.72727273e-01, 8.41269841e-01, 2.00707804e-01],
#        [9.98857356e-01, 6.31738743e-02, 8.27586207e-01, ...,
#         8.18181818e-01, 7.93650794e-01, 4.25778887e-01],
#        [9.98967388e-01, 6.43362328e-02, 8.62068966e-01, ...,
#         8.63636364e-01, 5.87301587e-01, 1.27076913e-01],
#        ...,
#        [9.98188697e-01, 9.70743614e-02, 8.27586207e-01, ...,
#         8.63636364e-01, 5.87301587e-01, 8.78475686e-02],
#        [8.22263790e-01, 8.69630117e-01, 4.48275862e-01, ...,
#         5.90909091e-01, 7.93650794e-01, 4.76909593e-01],
#        [8.85126156e-01, 8.19136832e-01, 6.20689655e-01, ...,
#         6.36363636e-01, 9.84126984e-01, 9.96488866e-01]])

# %%
inputs = tf.keras.Input(shape=(45,))

x = tf.keras.layers.Dense(40,activation='relu')(inputs)
x = tf.keras.layers.Dense(20,activation='relu')(x)
x = tf.keras.layers.Dropout(0.25)(x)

output = tf.keras.layers.Dense(3,activation='softmax')(x)

model = tf.keras.Model(inputs=inputs,outputs=output)
print(type())
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 45)]              0
#
#  dense (Dense)               (None, 40)                1840
#
#  dense_1 (Dense)             (None, 20)                820
#
#  dropout (Dropout)           (None, 20)                0
#
#  dense_2 (Dense)             (None, 3)                 63
#
# =================================================================
# Total params: 2,723
# Trainable params: 2,723
# Non-trainable params: 0
# _________________________________________________________________
# 2023-04-25 21:36:38.814716: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-25 21:36:40.114559: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 343 MB memory:  -> device: 0, name: Tesla V100-PCIE-16GB, pci bus id: 0000:3b:00.0, compute capability: 7.0

# %%
model.compile(
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.0005),
    metrics=["accuracy"],
)

# %%
model.fit(x_train, y_train, batch_size=32, epochs=150, validation_split=0.2)
test_score = model.evaluate(x_test, y_test, verbose=2)
print("Test loss: ", test_score[0])
print("Test accuracy: ", test_score[1])
# Out:
# Epoch 1/150
# /home/ok_sikha/anaconda3/envs/tf_gpu_segnet/lib/python3.9/site-packages/keras/backend.py:5582: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 9/9 [==============================] - 2s 48ms/step - loss: 1.1538 - accuracy: 0.2997 - val_loss: 1.0951 - val_accuracy: 0.4028
# Epoch 2/150
# 9/9 [==============================] - 0s 20ms/step - loss: 1.0910 - accuracy: 0.4251 - val_loss: 1.0665 - val_accuracy: 0.4167
# Epoch 3/150
# 9/9 [==============================] - 0s 20ms/step - loss: 1.0786 - accuracy: 0.4077 - val_loss: 1.0650 - val_accuracy: 0.4167
# Epoch 4/150
# 9/9 [==============================] - 0s 14ms/step - loss: 1.0795 - accuracy: 0.3693 - val_loss: 1.0523 - val_accuracy: 0.4167
# Epoch 5/150
# 9/9 [==============================] - 0s 17ms/step - loss: 1.0510 - accuracy: 0.4390 - val_loss: 1.0451 - val_accuracy: 0.4306
# Epoch 6/150
# 9/9 [==============================] - 0s 15ms/step - loss: 1.0390 - accuracy: 0.4425 - val_loss: 1.0436 - val_accuracy: 0.4444
# Epoch 7/150
# 9/9 [==============================] - 0s 14ms/step - loss: 1.0469 - accuracy: 0.4599 - val_loss: 1.0395 - val_accuracy: 0.4167
# Epoch 8/150
# 9/9 [==============================] - 0s 19ms/step - loss: 1.0275 - accuracy: 0.4739 - val_loss: 1.0313 - val_accuracy: 0.5139
# Epoch 9/150
# 9/9 [==============================] - 0s 15ms/step - loss: 1.0353 - accuracy: 0.4390 - val_loss: 1.0251 - val_accuracy: 0.5833
# Epoch 10/150
# 9/9 [==============================] - 0s 18ms/step - loss: 1.0153 - accuracy: 0.4843 - val_loss: 1.0213 - val_accuracy: 0.5417
# Epoch 11/150
# 9/9 [==============================] - 0s 18ms/step - loss: 1.0117 - accuracy: 0.4739 - val_loss: 1.0136 - val_accuracy: 0.5278
# Epoch 12/150
# 9/9 [==============================] - 0s 20ms/step - loss: 1.0010 - accuracy: 0.5087 - val_loss: 1.0068 - val_accuracy: 0.5278
# Epoch 13/150
# 9/9 [==============================] - 0s 22ms/step - loss: 0.9962 - accuracy: 0.4843 - val_loss: 0.9920 - val_accuracy: 0.6111
# Epoch 14/150
# 9/9 [==============================] - 0s 14ms/step - loss: 0.9826 - accuracy: 0.5226 - val_loss: 0.9850 - val_accuracy: 0.5972
# Epoch 15/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.9769 - accuracy: 0.5087 - val_loss: 0.9808 - val_accuracy: 0.5972
# Epoch 16/150
# 9/9 [==============================] - 0s 14ms/step - loss: 0.9882 - accuracy: 0.4599 - val_loss: 0.9765 - val_accuracy: 0.5556
# Epoch 17/150
# 9/9 [==============================] - 0s 17ms/step - loss: 0.9799 - accuracy: 0.5122 - val_loss: 0.9629 - val_accuracy: 0.6389
# Epoch 18/150
# 9/9 [==============================] - 0s 11ms/step - loss: 0.9606 - accuracy: 0.5226 - val_loss: 0.9573 - val_accuracy: 0.5972
# Epoch 19/150
# 9/9 [==============================] - 0s 16ms/step - loss: 0.9740 - accuracy: 0.5192 - val_loss: 0.9508 - val_accuracy: 0.6111
# Epoch 20/150
# 9/9 [==============================] - 0s 14ms/step - loss: 0.9355 - accuracy: 0.5784 - val_loss: 0.9392 - val_accuracy: 0.6389
# Epoch 21/150
# 9/9 [==============================] - 0s 11ms/step - loss: 0.9445 - accuracy: 0.5575 - val_loss: 0.9257 - val_accuracy: 0.6667
# Epoch 22/150
# 9/9 [==============================] - 0s 9ms/step - loss: 0.9227 - accuracy: 0.5923 - val_loss: 0.9207 - val_accuracy: 0.6528
# Epoch 23/150
# 9/9 [==============================] - 0s 19ms/step - loss: 0.9128 - accuracy: 0.5784 - val_loss: 0.9057 - val_accuracy: 0.6667
# Epoch 24/150
# 9/9 [==============================] - 0s 15ms/step - loss: 0.8923 - accuracy: 0.5993 - val_loss: 0.8817 - val_accuracy: 0.6528
# Epoch 25/150
# 9/9 [==============================] - 0s 19ms/step - loss: 0.9000 - accuracy: 0.5784 - val_loss: 0.8702 - val_accuracy: 0.7222
# Epoch 26/150
# 9/9 [==============================] - 0s 9ms/step - loss: 0.8793 - accuracy: 0.6272 - val_loss: 0.8635 - val_accuracy: 0.7083
# Epoch 27/150
# 9/9 [==============================] - 0s 18ms/step - loss: 0.8690 - accuracy: 0.5958 - val_loss: 0.8469 - val_accuracy: 0.7361
# Epoch 28/150
# 9/9 [==============================] - 0s 19ms/step - loss: 0.8663 - accuracy: 0.5854 - val_loss: 0.8367 - val_accuracy: 0.7083
# Epoch 29/150
# 9/9 [==============================] - 0s 11ms/step - loss: 0.8488 - accuracy: 0.6341 - val_loss: 0.8259 - val_accuracy: 0.7083
# Epoch 30/150
# 9/9 [==============================] - 0s 16ms/step - loss: 0.8448 - accuracy: 0.6063 - val_loss: 0.8034 - val_accuracy: 0.7361
# Epoch 31/150
# 9/9 [==============================] - 0s 26ms/step - loss: 0.8332 - accuracy: 0.6028 - val_loss: 0.7975 - val_accuracy: 0.7222
# Epoch 32/150
# 9/9 [==============================] - 0s 24ms/step - loss: 0.8186 - accuracy: 0.6307 - val_loss: 0.7816 - val_accuracy: 0.7500
# Epoch 33/150
# 9/9 [==============================] - 0s 10ms/step - loss: 0.8074 - accuracy: 0.6063 - val_loss: 0.7622 - val_accuracy: 0.7361
# Epoch 34/150
# 9/9 [==============================] - 0s 11ms/step - loss: 0.7957 - accuracy: 0.6516 - val_loss: 0.7551 - val_accuracy: 0.7361
# Epoch 35/150
# 9/9 [==============================] - 0s 13ms/step - loss: 0.7965 - accuracy: 0.6063 - val_loss: 0.7425 - val_accuracy: 0.7361
# Epoch 36/150
# 9/9 [==============================] - 0s 8ms/step - loss: 0.7966 - accuracy: 0.5819 - val_loss: 0.7312 - val_accuracy: 0.7361
# Epoch 37/150
# 9/9 [==============================] - 0s 19ms/step - loss: 0.7672 - accuracy: 0.6272 - val_loss: 0.7312 - val_accuracy: 0.7083
# Epoch 38/150
# 9/9 [==============================] - 0s 10ms/step - loss: 0.7514 - accuracy: 0.6481 - val_loss: 0.7055 - val_accuracy: 0.7222
# Epoch 39/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.7411 - accuracy: 0.6655 - val_loss: 0.6938 - val_accuracy: 0.7361
# Epoch 40/150
# 9/9 [==============================] - 0s 14ms/step - loss: 0.7122 - accuracy: 0.6899 - val_loss: 0.6831 - val_accuracy: 0.7500
# Epoch 41/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.7372 - accuracy: 0.6237 - val_loss: 0.6687 - val_accuracy: 0.7361
# Epoch 42/150
# 9/9 [==============================] - 0s 13ms/step - loss: 0.6991 - accuracy: 0.6690 - val_loss: 0.6635 - val_accuracy: 0.7361
# Epoch 43/150
# 9/9 [==============================] - 0s 22ms/step - loss: 0.7056 - accuracy: 0.6481 - val_loss: 0.6535 - val_accuracy: 0.7500
# Epoch 44/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.7103 - accuracy: 0.6341 - val_loss: 0.6446 - val_accuracy: 0.7361
# Epoch 45/150
# 9/9 [==============================] - 0s 15ms/step - loss: 0.6672 - accuracy: 0.6690 - val_loss: 0.6320 - val_accuracy: 0.7500
# Epoch 46/150
# 9/9 [==============================] - 0s 16ms/step - loss: 0.6742 - accuracy: 0.6655 - val_loss: 0.6278 - val_accuracy: 0.7500
# Epoch 47/150
# 9/9 [==============================] - 0s 18ms/step - loss: 0.6626 - accuracy: 0.6620 - val_loss: 0.6161 - val_accuracy: 0.7500
# Epoch 48/150
# 9/9 [==============================] - 0s 21ms/step - loss: 0.6646 - accuracy: 0.6899 - val_loss: 0.6047 - val_accuracy: 0.7500
# Epoch 49/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.6540 - accuracy: 0.6620 - val_loss: 0.5977 - val_accuracy: 0.7500
# Epoch 50/150
# 9/9 [==============================] - 0s 20ms/step - loss: 0.6585 - accuracy: 0.6829 - val_loss: 0.5938 - val_accuracy: 0.7500
# Epoch 51/150
# 9/9 [==============================] - 0s 10ms/step - loss: 0.6427 - accuracy: 0.6760 - val_loss: 0.5858 - val_accuracy: 0.7500
# Epoch 52/150
# 9/9 [==============================] - 0s 21ms/step - loss: 0.6499 - accuracy: 0.6760 - val_loss: 0.5791 - val_accuracy: 0.7639
# Epoch 53/150
# 9/9 [==============================] - 0s 9ms/step - loss: 0.6346 - accuracy: 0.6690 - val_loss: 0.5812 - val_accuracy: 0.7500
# Epoch 54/150
# 9/9 [==============================] - 0s 16ms/step - loss: 0.6186 - accuracy: 0.6934 - val_loss: 0.5702 - val_accuracy: 0.7639
# Epoch 55/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.6236 - accuracy: 0.6829 - val_loss: 0.5667 - val_accuracy: 0.7639
# Epoch 56/150
# 9/9 [==============================] - 0s 20ms/step - loss: 0.6318 - accuracy: 0.6516 - val_loss: 0.5581 - val_accuracy: 0.7639
# Epoch 57/150
# 9/9 [==============================] - 0s 24ms/step - loss: 0.6083 - accuracy: 0.6899 - val_loss: 0.5522 - val_accuracy: 0.7917
# Epoch 58/150
# 9/9 [==============================] - 0s 14ms/step - loss: 0.5948 - accuracy: 0.7108 - val_loss: 0.5458 - val_accuracy: 0.7917
# Epoch 59/150
# 9/9 [==============================] - 0s 14ms/step - loss: 0.5994 - accuracy: 0.6899 - val_loss: 0.5433 - val_accuracy: 0.7917
# Epoch 60/150
# 9/9 [==============================] - 0s 17ms/step - loss: 0.5859 - accuracy: 0.7352 - val_loss: 0.5468 - val_accuracy: 0.7639
# Epoch 61/150
# 9/9 [==============================] - 0s 16ms/step - loss: 0.5830 - accuracy: 0.7352 - val_loss: 0.5367 - val_accuracy: 0.7500
# Epoch 62/150
# 9/9 [==============================] - 0s 18ms/step - loss: 0.5923 - accuracy: 0.7247 - val_loss: 0.5376 - val_accuracy: 0.7639
# Epoch 63/150
# 9/9 [==============================] - 0s 20ms/step - loss: 0.5800 - accuracy: 0.7108 - val_loss: 0.5280 - val_accuracy: 0.8472
# Epoch 64/150
# 9/9 [==============================] - 0s 10ms/step - loss: 0.5536 - accuracy: 0.7666 - val_loss: 0.5231 - val_accuracy: 0.8194
# Epoch 65/150
# 9/9 [==============================] - 0s 9ms/step - loss: 0.5722 - accuracy: 0.7387 - val_loss: 0.5203 - val_accuracy: 0.8333
# Epoch 66/150
# 9/9 [==============================] - 0s 15ms/step - loss: 0.5614 - accuracy: 0.7422 - val_loss: 0.5209 - val_accuracy: 0.7778
# Epoch 67/150
# 9/9 [==============================] - 0s 18ms/step - loss: 0.5537 - accuracy: 0.7247 - val_loss: 0.5113 - val_accuracy: 0.8333
# Epoch 68/150
# 9/9 [==============================] - 0s 9ms/step - loss: 0.5546 - accuracy: 0.7666 - val_loss: 0.5150 - val_accuracy: 0.7917
# Epoch 69/150
# 9/9 [==============================] - 0s 15ms/step - loss: 0.5645 - accuracy: 0.7143 - val_loss: 0.5075 - val_accuracy: 0.8056
# Epoch 70/150
# 9/9 [==============================] - 0s 19ms/step - loss: 0.5345 - accuracy: 0.7735 - val_loss: 0.4971 - val_accuracy: 0.8472
# Epoch 71/150
# 9/9 [==============================] - 0s 20ms/step - loss: 0.5386 - accuracy: 0.7700 - val_loss: 0.4992 - val_accuracy: 0.8194
# Epoch 72/150
# 9/9 [==============================] - 0s 11ms/step - loss: 0.5579 - accuracy: 0.7352 - val_loss: 0.4953 - val_accuracy: 0.8333
# Epoch 73/150
# 9/9 [==============================] - 0s 21ms/step - loss: 0.5305 - accuracy: 0.7735 - val_loss: 0.4946 - val_accuracy: 0.8056
# Epoch 74/150
# 9/9 [==============================] - 0s 22ms/step - loss: 0.5461 - accuracy: 0.7735 - val_loss: 0.4867 - val_accuracy: 0.8333
# Epoch 75/150
# 9/9 [==============================] - 0s 16ms/step - loss: 0.5358 - accuracy: 0.7596 - val_loss: 0.4864 - val_accuracy: 0.8194
# Epoch 76/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.5245 - accuracy: 0.7979 - val_loss: 0.4833 - val_accuracy: 0.8333
# Epoch 77/150
# 9/9 [==============================] - 0s 11ms/step - loss: 0.5249 - accuracy: 0.7666 - val_loss: 0.4813 - val_accuracy: 0.8333
# Epoch 78/150
# 9/9 [==============================] - 0s 20ms/step - loss: 0.5130 - accuracy: 0.7700 - val_loss: 0.4806 - val_accuracy: 0.8472
# Epoch 79/150
# 9/9 [==============================] - 0s 11ms/step - loss: 0.5095 - accuracy: 0.7700 - val_loss: 0.4739 - val_accuracy: 0.8333
# Epoch 80/150
# 9/9 [==============================] - 0s 15ms/step - loss: 0.5208 - accuracy: 0.7456 - val_loss: 0.4777 - val_accuracy: 0.8333
# Epoch 81/150
# 9/9 [==============================] - 0s 16ms/step - loss: 0.5135 - accuracy: 0.7944 - val_loss: 0.4703 - val_accuracy: 0.8333
# Epoch 82/150
# 9/9 [==============================] - 0s 13ms/step - loss: 0.5067 - accuracy: 0.7909 - val_loss: 0.4718 - val_accuracy: 0.8333
# Epoch 83/150
# 9/9 [==============================] - 0s 21ms/step - loss: 0.5001 - accuracy: 0.8084 - val_loss: 0.4653 - val_accuracy: 0.8333
# Epoch 84/150
# 9/9 [==============================] - 0s 25ms/step - loss: 0.5000 - accuracy: 0.7875 - val_loss: 0.4641 - val_accuracy: 0.8333
# Epoch 85/150
# 9/9 [==============================] - 0s 14ms/step - loss: 0.4837 - accuracy: 0.8153 - val_loss: 0.4703 - val_accuracy: 0.8611
# Epoch 86/150
# 9/9 [==============================] - 0s 20ms/step - loss: 0.4887 - accuracy: 0.8153 - val_loss: 0.4643 - val_accuracy: 0.8611
# Epoch 87/150
# 9/9 [==============================] - 0s 11ms/step - loss: 0.4832 - accuracy: 0.8188 - val_loss: 0.4517 - val_accuracy: 0.8611
# Epoch 88/150
# 9/9 [==============================] - 0s 14ms/step - loss: 0.4878 - accuracy: 0.7944 - val_loss: 0.4680 - val_accuracy: 0.8472
# Epoch 89/150
# 9/9 [==============================] - 0s 21ms/step - loss: 0.4858 - accuracy: 0.8049 - val_loss: 0.4518 - val_accuracy: 0.8611
# Epoch 90/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.4825 - accuracy: 0.8258 - val_loss: 0.4575 - val_accuracy: 0.8611
# Epoch 91/150
# 9/9 [==============================] - 0s 11ms/step - loss: 0.4782 - accuracy: 0.8223 - val_loss: 0.4565 - val_accuracy: 0.8611
# Epoch 92/150
# 9/9 [==============================] - 0s 13ms/step - loss: 0.4720 - accuracy: 0.8084 - val_loss: 0.4488 - val_accuracy: 0.8472
# Epoch 93/150
# 9/9 [==============================] - 0s 11ms/step - loss: 0.4785 - accuracy: 0.8084 - val_loss: 0.4523 - val_accuracy: 0.8611
# Epoch 94/150
# 9/9 [==============================] - 0s 10ms/step - loss: 0.4756 - accuracy: 0.8188 - val_loss: 0.4419 - val_accuracy: 0.8889
# Epoch 95/150
# 9/9 [==============================] - 0s 20ms/step - loss: 0.4567 - accuracy: 0.8362 - val_loss: 0.4431 - val_accuracy: 0.8472
# Epoch 96/150
# 9/9 [==============================] - 0s 17ms/step - loss: 0.4644 - accuracy: 0.8293 - val_loss: 0.4526 - val_accuracy: 0.8611
# Epoch 97/150
# 9/9 [==============================] - 0s 20ms/step - loss: 0.4685 - accuracy: 0.8223 - val_loss: 0.4443 - val_accuracy: 0.8889
# Epoch 98/150
# 9/9 [==============================] - 0s 14ms/step - loss: 0.4486 - accuracy: 0.8571 - val_loss: 0.4436 - val_accuracy: 0.8611
# Epoch 99/150
# 9/9 [==============================] - 0s 18ms/step - loss: 0.4499 - accuracy: 0.8467 - val_loss: 0.4360 - val_accuracy: 0.8472
# Epoch 100/150
# 9/9 [==============================] - 0s 9ms/step - loss: 0.4637 - accuracy: 0.8118 - val_loss: 0.4369 - val_accuracy: 0.8750
# Epoch 101/150
# 9/9 [==============================] - 0s 13ms/step - loss: 0.4578 - accuracy: 0.8223 - val_loss: 0.4417 - val_accuracy: 0.8611
# Epoch 102/150
# 9/9 [==============================] - 0s 19ms/step - loss: 0.4483 - accuracy: 0.8397 - val_loss: 0.4347 - val_accuracy: 0.8611
# Epoch 103/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.4592 - accuracy: 0.8188 - val_loss: 0.4366 - val_accuracy: 0.8611
# Epoch 104/150
# 9/9 [==============================] - 0s 14ms/step - loss: 0.4466 - accuracy: 0.8258 - val_loss: 0.4252 - val_accuracy: 0.8611
# Epoch 105/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.4323 - accuracy: 0.8328 - val_loss: 0.4360 - val_accuracy: 0.8611
# Epoch 106/150
# 9/9 [==============================] - 0s 15ms/step - loss: 0.4511 - accuracy: 0.8188 - val_loss: 0.4254 - val_accuracy: 0.8750
# Epoch 107/150
# 9/9 [==============================] - 0s 16ms/step - loss: 0.4410 - accuracy: 0.8293 - val_loss: 0.4437 - val_accuracy: 0.8611
# Epoch 108/150
# 9/9 [==============================] - 0s 16ms/step - loss: 0.4521 - accuracy: 0.8397 - val_loss: 0.4230 - val_accuracy: 0.8750
# Epoch 109/150
# 9/9 [==============================] - 0s 10ms/step - loss: 0.4377 - accuracy: 0.8223 - val_loss: 0.4282 - val_accuracy: 0.8611
# Epoch 110/150
# 9/9 [==============================] - 0s 11ms/step - loss: 0.4362 - accuracy: 0.8502 - val_loss: 0.4226 - val_accuracy: 0.8750
# Epoch 111/150
# 9/9 [==============================] - 0s 16ms/step - loss: 0.4238 - accuracy: 0.8711 - val_loss: 0.4314 - val_accuracy: 0.8750
# Epoch 112/150
# 9/9 [==============================] - 0s 14ms/step - loss: 0.4325 - accuracy: 0.8571 - val_loss: 0.4182 - val_accuracy: 0.8750
# Epoch 113/150
# 9/9 [==============================] - 0s 19ms/step - loss: 0.4090 - accuracy: 0.8711 - val_loss: 0.4162 - val_accuracy: 0.8611
# Epoch 114/150
# 9/9 [==============================] - 0s 17ms/step - loss: 0.4214 - accuracy: 0.8397 - val_loss: 0.4178 - val_accuracy: 0.8750
# Epoch 115/150
# 9/9 [==============================] - 0s 28ms/step - loss: 0.4056 - accuracy: 0.8537 - val_loss: 0.4126 - val_accuracy: 0.8750
# Epoch 116/150
# 9/9 [==============================] - 0s 11ms/step - loss: 0.4209 - accuracy: 0.8362 - val_loss: 0.4030 - val_accuracy: 0.9028
# Epoch 117/150
# 9/9 [==============================] - 0s 13ms/step - loss: 0.4050 - accuracy: 0.8467 - val_loss: 0.4171 - val_accuracy: 0.9028
# Epoch 118/150
# 9/9 [==============================] - 0s 11ms/step - loss: 0.4118 - accuracy: 0.8537 - val_loss: 0.4053 - val_accuracy: 0.9028
# Epoch 119/150
# 9/9 [==============================] - 0s 13ms/step - loss: 0.4119 - accuracy: 0.8502 - val_loss: 0.4065 - val_accuracy: 0.8750
# Epoch 120/150
# 9/9 [==============================] - 0s 13ms/step - loss: 0.3991 - accuracy: 0.8641 - val_loss: 0.4023 - val_accuracy: 0.9028
# Epoch 121/150
# 9/9 [==============================] - 0s 10ms/step - loss: 0.3976 - accuracy: 0.8746 - val_loss: 0.3995 - val_accuracy: 0.9028
# Epoch 122/150
# 9/9 [==============================] - 0s 17ms/step - loss: 0.4045 - accuracy: 0.8397 - val_loss: 0.4075 - val_accuracy: 0.9028
# Epoch 123/150
# 9/9 [==============================] - 0s 10ms/step - loss: 0.3939 - accuracy: 0.8746 - val_loss: 0.3962 - val_accuracy: 0.9028
# Epoch 124/150
# 9/9 [==============================] - 0s 10ms/step - loss: 0.4117 - accuracy: 0.8502 - val_loss: 0.3942 - val_accuracy: 0.9028
# Epoch 125/150
# 9/9 [==============================] - 0s 22ms/step - loss: 0.4041 - accuracy: 0.8571 - val_loss: 0.3941 - val_accuracy: 0.8889
# Epoch 126/150
# 9/9 [==============================] - 0s 8ms/step - loss: 0.3768 - accuracy: 0.8676 - val_loss: 0.3946 - val_accuracy: 0.8889
# Epoch 127/150
# 9/9 [==============================] - 0s 18ms/step - loss: 0.3820 - accuracy: 0.8676 - val_loss: 0.3910 - val_accuracy: 0.9028
# Epoch 128/150
# 9/9 [==============================] - 0s 18ms/step - loss: 0.4044 - accuracy: 0.8537 - val_loss: 0.3947 - val_accuracy: 0.8889
# Epoch 129/150
# 9/9 [==============================] - 0s 18ms/step - loss: 0.3961 - accuracy: 0.8537 - val_loss: 0.3871 - val_accuracy: 0.9167
# Epoch 130/150
# 9/9 [==============================] - 0s 18ms/step - loss: 0.3931 - accuracy: 0.8746 - val_loss: 0.4006 - val_accuracy: 0.8889
# Epoch 131/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.3864 - accuracy: 0.8641 - val_loss: 0.3902 - val_accuracy: 0.9167
# Epoch 132/150
# 9/9 [==============================] - 0s 19ms/step - loss: 0.3663 - accuracy: 0.8920 - val_loss: 0.3874 - val_accuracy: 0.8889
# Epoch 133/150
# 9/9 [==============================] - 0s 11ms/step - loss: 0.3778 - accuracy: 0.8571 - val_loss: 0.3871 - val_accuracy: 0.8889
# Epoch 134/150
# 9/9 [==============================] - 0s 10ms/step - loss: 0.3718 - accuracy: 0.8815 - val_loss: 0.3813 - val_accuracy: 0.9167
# Epoch 135/150
# 9/9 [==============================] - 0s 21ms/step - loss: 0.3696 - accuracy: 0.8955 - val_loss: 0.3875 - val_accuracy: 0.9028
# Epoch 136/150
# 9/9 [==============================] - 0s 8ms/step - loss: 0.3749 - accuracy: 0.8780 - val_loss: 0.3881 - val_accuracy: 0.8889
# Epoch 137/150
# 9/9 [==============================] - 0s 18ms/step - loss: 0.3715 - accuracy: 0.8641 - val_loss: 0.3784 - val_accuracy: 0.8889
# Epoch 138/150
# 9/9 [==============================] - 0s 15ms/step - loss: 0.3662 - accuracy: 0.8711 - val_loss: 0.3831 - val_accuracy: 0.8889
# Epoch 139/150
# 9/9 [==============================] - 0s 17ms/step - loss: 0.3712 - accuracy: 0.8780 - val_loss: 0.3821 - val_accuracy: 0.9444
# Epoch 140/150
# 9/9 [==============================] - 0s 14ms/step - loss: 0.3687 - accuracy: 0.8606 - val_loss: 0.3754 - val_accuracy: 0.9306
# Epoch 141/150
# 9/9 [==============================] - 0s 18ms/step - loss: 0.3697 - accuracy: 0.8746 - val_loss: 0.3708 - val_accuracy: 0.9028
# Epoch 142/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.3681 - accuracy: 0.8641 - val_loss: 0.3786 - val_accuracy: 0.9028
# Epoch 143/150
# 9/9 [==============================] - 0s 20ms/step - loss: 0.3617 - accuracy: 0.8885 - val_loss: 0.3715 - val_accuracy: 0.9306
# Epoch 144/150
# 9/9 [==============================] - 0s 26ms/step - loss: 0.3564 - accuracy: 0.8676 - val_loss: 0.3780 - val_accuracy: 0.9167
# Epoch 145/150
# 9/9 [==============================] - 0s 16ms/step - loss: 0.3441 - accuracy: 0.8990 - val_loss: 0.3643 - val_accuracy: 0.9167
# Epoch 146/150
# 9/9 [==============================] - 0s 19ms/step - loss: 0.3513 - accuracy: 0.8746 - val_loss: 0.3633 - val_accuracy: 0.9167
# Epoch 147/150
# 9/9 [==============================] - 0s 10ms/step - loss: 0.3485 - accuracy: 0.8955 - val_loss: 0.3759 - val_accuracy: 0.9028
# Epoch 148/150
# 9/9 [==============================] - 0s 18ms/step - loss: 0.3654 - accuracy: 0.8815 - val_loss: 0.3615 - val_accuracy: 0.9306
# Epoch 149/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.3522 - accuracy: 0.8537 - val_loss: 0.3723 - val_accuracy: 0.9583
# Epoch 150/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.3534 - accuracy: 0.8815 - val_loss: 0.3598 - val_accuracy: 0.9306
# 3/3 - 0s - loss: 0.3194 - accuracy: 0.9111 - 76ms/epoch - 25ms/step
# Test loss:  0.31937262415885925
# Test accuracy:  0.9111111164093018

# %% [markdown]
# ## QUANT AWARE TRAINING

# %%
import tensorflow_model_optimization as tfmot

quantize_model = tfmot.quantization.keras.quantize_model

q_aware_model = quantize_model(model)

q_aware_model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

q_aware_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 45)]              0
#
#  quantize_layer (QuantizeLay  (None, 45)               3
#  er)
#
#  quant_dense (QuantizeWrappe  (None, 40)               1845
#  rV2)
#
#  quant_dense_1 (QuantizeWrap  (None, 20)               825
#  perV2)
#
#  quant_dropout (QuantizeWrap  (None, 20)               1
#  perV2)
#
#  quant_dense_2 (QuantizeWrap  (None, 3)                68
#  perV2)
#
# =================================================================
# Total params: 2,742
# Trainable params: 2,723
# Non-trainable params: 19
# _________________________________________________________________

# %%
q_aware_model.fit(x_train, y_train, epochs=50, validation_split=0.1)
# Out:
# Epoch 1/50
# 11/11 [==============================] - 1s 35ms/step - loss: 0.3617 - accuracy: 0.8731 - val_loss: 0.3044 - val_accuracy: 0.8611
# Epoch 2/50
# 11/11 [==============================] - 0s 21ms/step - loss: 0.3660 - accuracy: 0.8793 - val_loss: 0.2933 - val_accuracy: 0.8889
# Epoch 3/50
# 11/11 [==============================] - 0s 10ms/step - loss: 0.3732 - accuracy: 0.8545 - val_loss: 0.3001 - val_accuracy: 0.9167
# Epoch 4/50
# 11/11 [==============================] - 0s 18ms/step - loss: 0.3616 - accuracy: 0.8514 - val_loss: 0.2854 - val_accuracy: 0.9444
# Epoch 5/50
# 11/11 [==============================] - 0s 20ms/step - loss: 0.3381 - accuracy: 0.9071 - val_loss: 0.2804 - val_accuracy: 0.9722
# Epoch 6/50
# 11/11 [==============================] - 0s 11ms/step - loss: 0.3368 - accuracy: 0.8700 - val_loss: 0.2892 - val_accuracy: 0.8889
# Epoch 7/50
# 11/11 [==============================] - 0s 19ms/step - loss: 0.3352 - accuracy: 0.8885 - val_loss: 0.2862 - val_accuracy: 0.9444
# Epoch 8/50
# 11/11 [==============================] - 0s 15ms/step - loss: 0.3406 - accuracy: 0.8824 - val_loss: 0.2865 - val_accuracy: 0.9722
# Epoch 9/50
# 11/11 [==============================] - 0s 15ms/step - loss: 0.3368 - accuracy: 0.8885 - val_loss: 0.2782 - val_accuracy: 0.9444
# Epoch 10/50
# 11/11 [==============================] - 0s 13ms/step - loss: 0.3325 - accuracy: 0.8885 - val_loss: 0.2907 - val_accuracy: 0.8611
# Epoch 11/50
# 11/11 [==============================] - 0s 18ms/step - loss: 0.3227 - accuracy: 0.9071 - val_loss: 0.2712 - val_accuracy: 0.9722
# Epoch 12/50
# 11/11 [==============================] - 0s 20ms/step - loss: 0.3454 - accuracy: 0.8576 - val_loss: 0.2767 - val_accuracy: 0.9167
# Epoch 13/50
# 11/11 [==============================] - 0s 25ms/step - loss: 0.3162 - accuracy: 0.8854 - val_loss: 0.2719 - val_accuracy: 0.9167
# Epoch 14/50
# 11/11 [==============================] - 0s 19ms/step - loss: 0.3085 - accuracy: 0.8978 - val_loss: 0.2774 - val_accuracy: 0.9167
# Epoch 15/50
# 11/11 [==============================] - 0s 10ms/step - loss: 0.3339 - accuracy: 0.8638 - val_loss: 0.2821 - val_accuracy: 0.8611
# Epoch 16/50
# 11/11 [==============================] - 0s 15ms/step - loss: 0.3137 - accuracy: 0.8885 - val_loss: 0.2581 - val_accuracy: 0.9722
# Epoch 17/50
# 11/11 [==============================] - 0s 15ms/step - loss: 0.3050 - accuracy: 0.8885 - val_loss: 0.2610 - val_accuracy: 0.9167
# Epoch 18/50
# 11/11 [==============================] - 0s 18ms/step - loss: 0.3140 - accuracy: 0.8824 - val_loss: 0.2680 - val_accuracy: 0.9167
# Epoch 19/50
# 11/11 [==============================] - 0s 8ms/step - loss: 0.3239 - accuracy: 0.8545 - val_loss: 0.2784 - val_accuracy: 0.8889
# Epoch 20/50
# 11/11 [==============================] - 0s 16ms/step - loss: 0.3267 - accuracy: 0.8762 - val_loss: 0.2580 - val_accuracy: 0.9444
# Epoch 21/50
# 11/11 [==============================] - 0s 12ms/step - loss: 0.3143 - accuracy: 0.8824 - val_loss: 0.2737 - val_accuracy: 0.8889
# Epoch 22/50
# 11/11 [==============================] - 0s 16ms/step - loss: 0.2904 - accuracy: 0.9009 - val_loss: 0.2490 - val_accuracy: 0.9167
# Epoch 23/50
# 11/11 [==============================] - 0s 15ms/step - loss: 0.3026 - accuracy: 0.8638 - val_loss: 0.2485 - val_accuracy: 0.9722
# Epoch 24/50
# 11/11 [==============================] - 0s 12ms/step - loss: 0.2910 - accuracy: 0.9040 - val_loss: 0.2338 - val_accuracy: 0.9722
# Epoch 25/50
# 11/11 [==============================] - 0s 19ms/step - loss: 0.3024 - accuracy: 0.9040 - val_loss: 0.2482 - val_accuracy: 0.9722
# Epoch 26/50
# 11/11 [==============================] - 0s 15ms/step - loss: 0.3240 - accuracy: 0.8885 - val_loss: 0.2672 - val_accuracy: 0.9167
# Epoch 27/50
# 11/11 [==============================] - 0s 14ms/step - loss: 0.2998 - accuracy: 0.8854 - val_loss: 0.2328 - val_accuracy: 0.9722
# Epoch 28/50
# 11/11 [==============================] - 0s 12ms/step - loss: 0.2830 - accuracy: 0.8824 - val_loss: 0.2391 - val_accuracy: 0.9167
# Epoch 29/50
# 11/11 [==============================] - 0s 16ms/step - loss: 0.2903 - accuracy: 0.8854 - val_loss: 0.2364 - val_accuracy: 0.9722
# Epoch 30/50
# 11/11 [==============================] - 0s 16ms/step - loss: 0.2680 - accuracy: 0.9226 - val_loss: 0.2394 - val_accuracy: 0.9722
# Epoch 31/50
# 11/11 [==============================] - 0s 15ms/step - loss: 0.2800 - accuracy: 0.8978 - val_loss: 0.2415 - val_accuracy: 0.9444
# Epoch 32/50
# 11/11 [==============================] - 0s 11ms/step - loss: 0.2786 - accuracy: 0.9009 - val_loss: 0.2257 - val_accuracy: 0.9167
# Epoch 33/50
# 11/11 [==============================] - 0s 19ms/step - loss: 0.2781 - accuracy: 0.8947 - val_loss: 0.2755 - val_accuracy: 0.8889
# Epoch 34/50
# 11/11 [==============================] - 0s 11ms/step - loss: 0.2826 - accuracy: 0.9071 - val_loss: 0.2213 - val_accuracy: 0.9722
# Epoch 35/50
# 11/11 [==============================] - 0s 19ms/step - loss: 0.2734 - accuracy: 0.9226 - val_loss: 0.2163 - val_accuracy: 0.9444
# Epoch 36/50
# 11/11 [==============================] - 0s 10ms/step - loss: 0.2768 - accuracy: 0.9133 - val_loss: 0.2278 - val_accuracy: 1.0000
# Epoch 37/50
# 11/11 [==============================] - 0s 21ms/step - loss: 0.2565 - accuracy: 0.9226 - val_loss: 0.2198 - val_accuracy: 0.9722
# Epoch 38/50
# 11/11 [==============================] - 0s 14ms/step - loss: 0.2588 - accuracy: 0.9226 - val_loss: 0.2311 - val_accuracy: 0.9444
# Epoch 39/50
# 11/11 [==============================] - 0s 12ms/step - loss: 0.2665 - accuracy: 0.8916 - val_loss: 0.2301 - val_accuracy: 0.8889
# Epoch 40/50
# 11/11 [==============================] - 0s 12ms/step - loss: 0.2686 - accuracy: 0.9071 - val_loss: 0.2301 - val_accuracy: 0.9444
# Epoch 41/50
# 11/11 [==============================] - 0s 17ms/step - loss: 0.2890 - accuracy: 0.8947 - val_loss: 0.2165 - val_accuracy: 0.9722
# Epoch 42/50
# 11/11 [==============================] - 0s 10ms/step - loss: 0.2658 - accuracy: 0.8978 - val_loss: 0.2285 - val_accuracy: 0.9444
# Epoch 43/50
# 11/11 [==============================] - 0s 17ms/step - loss: 0.2613 - accuracy: 0.9009 - val_loss: 0.2109 - val_accuracy: 0.9722
# Epoch 44/50
# 11/11 [==============================] - 0s 13ms/step - loss: 0.2616 - accuracy: 0.9071 - val_loss: 0.2311 - val_accuracy: 0.9167
# Epoch 45/50
# 11/11 [==============================] - 0s 16ms/step - loss: 0.2572 - accuracy: 0.9133 - val_loss: 0.2227 - val_accuracy: 0.9444
# Epoch 46/50
# 11/11 [==============================] - 0s 15ms/step - loss: 0.2540 - accuracy: 0.9164 - val_loss: 0.2327 - val_accuracy: 0.9167
# Epoch 47/50
# 11/11 [==============================] - 0s 16ms/step - loss: 0.2715 - accuracy: 0.8916 - val_loss: 0.2181 - val_accuracy: 0.9444
# Epoch 48/50
# 11/11 [==============================] - 0s 9ms/step - loss: 0.2329 - accuracy: 0.9350 - val_loss: 0.2045 - val_accuracy: 0.9444
# Epoch 49/50
# 11/11 [==============================] - 0s 17ms/step - loss: 0.2465 - accuracy: 0.9071 - val_loss: 0.2079 - val_accuracy: 0.9722
# Epoch 50/50
# 11/11 [==============================] - 0s 16ms/step - loss: 0.2760 - accuracy: 0.8824 - val_loss: 0.2279 - val_accuracy: 0.9167

# %%
q_aware_model.evaluate(x_test,y_test)
# Out:
# 3/3 [==============================] - 0s 6ms/step - loss: 0.2635 - accuracy: 0.9222
# [0.26352202892303467, 0.9222221970558167]

# %% [markdown]
# ##  model to tflite

# %%
# non quantized

# %%
converter = tf.lite.TFLiteConverter.from_keras_model(q_aware_model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]

quantized_tflite_model = converter.convert()
# Out:
# WARNING:absl:Found untraced functions such as dense_layer_call_fn, dense_layer_call_and_return_conditional_losses, dense_1_layer_call_fn, dense_1_layer_call_and_return_conditional_losses, dropout_layer_call_fn while saving (showing 5 of 8). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /tmp/tmpxkc433yh/assets
# INFO:tensorflow:Assets written to: /tmp/tmpxkc433yh/assets
# /home/ok_sikha/anaconda3/envs/tf_gpu_segnet/lib/python3.9/site-packages/tensorflow/lite/python/convert.py:766: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn("Statistics for quantized inputs were expected, but not "
# 2023-04-25 21:37:18.578318: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:362] Ignored output_format.
# 2023-04-25 21:37:18.578381: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:365] Ignored drop_control_dependency.
# 2023-04-25 21:37:18.579450: I tensorflow/cc/saved_model/reader.cc:45] Reading SavedModel from: /tmp/tmpxkc433yh
# 2023-04-25 21:37:18.582999: I tensorflow/cc/saved_model/reader.cc:89] Reading meta graph with tags { serve }
# 2023-04-25 21:37:18.583080: I tensorflow/cc/saved_model/reader.cc:130] Reading SavedModel debug info (if present) from: /tmp/tmpxkc433yh
# 2023-04-25 21:37:18.608602: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:354] MLIR V1 optimization pass is not enabled
# 2023-04-25 21:37:18.615557: I tensorflow/cc/saved_model/loader.cc:229] Restoring SavedModel bundle.
# 2023-04-25 21:37:18.729833: I tensorflow/cc/saved_model/loader.cc:213] Running initialization op on SavedModel bundle at path: /tmp/tmpxkc433yh
# 2023-04-25 21:37:18.760146: I tensorflow/cc/saved_model/loader.cc:305] SavedModel load for tags { serve }; Status: success: OK. Took 180707 microseconds.
# 2023-04-25 21:37:18.848688: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.

# %%
# file = open( '84_quantization_aware_model.tflite' , 'wb' ) 
# file.write( quantized_tflite_model )

# %%
with open('93_quantization_aware_model.tflite', 'wb') as f:
  f.write(quantized_tflite_model)

# %% [markdown]
# # float16 quantized

# %%
# converter2 = tf.lite.TFLiteConverter.from_keras_model(q_aware_model)
# converter2.optimizations = [tf.lite.Optimize.DEFAULT]

# converter2.target_spec.supported_types = [tf.float16]

# float16_quantized_tflite_model = converter2.convert()

# %%
# file = open( 'float16_quantized_model.tflite' , 'wb' ) 
# file.write( float16_quantized_tflite_model )
